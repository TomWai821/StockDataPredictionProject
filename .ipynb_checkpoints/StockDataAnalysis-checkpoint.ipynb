# %%
# For data analysis and predictions
import numpy as np
import pandas as pd

# For preprocessing and error detection
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# For data Training (RNN, CNN, LSTM)
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, SimpleRNN, LSTM, Dense, Input, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import RootMeanSquaredError

# For Vector Auto Regression
from statsmodels.tsa.vector_ar.var_model import VAR

# For data visualize
import matplotlib.pyplot as plt
import seaborn as sns

# %%
csvData = pd.read_csv("./RawData/ADANIPORTS.csv", index_col=['Date'], parse_dates=['Date']);
df = pd.DataFrame(csvData);
df = df.drop(columns=['Trades', 'Series', 'Symbol']);

# %%
# display the columns in dataframe
print(df.columns);

# display how many data in csv file (row, column)
print(df.shape);
# Out:
# Index(['Prev Close', 'Open', 'High', 'Low', 'Last', 'Close', 'VWAP', 'Volume',
#        'Turnover', 'Deliverable Volume', '%Deliverble'],
#       dtype='object')
# (3322, 11)

# %%
# display the variable types of column
print(df.dtypes);
# Out:
# Prev Close            float64
# Open                  float64
# High                  float64
# Low                   float64
# Last                  float64
# Close                 float64
# VWAP                  float64
# Volume                  int64
# Turnover              float64
# Deliverable Volume      int64
# %Deliverble           float64
# dtype: object

# %%
print(df.head());
# Out:
#             Prev Close    Open     High    Low   Last   Close    VWAP  \
# Date
# 2007-11-27      440.00  770.00  1050.00  770.0  959.0  962.90  984.72
# 2007-11-28      962.90  984.00   990.00  874.0  885.0  893.90  941.38
# 2007-11-29      893.90  909.00   914.75  841.0  887.0  884.20  888.09
# 2007-11-30      884.20  890.00   958.00  890.0  929.0  921.55  929.17
# 2007-12-03      921.55  939.75   995.00  922.0  980.0  969.30  965.65
#
#               Volume      Turnover  Deliverable Volume  %Deliverble
# Date
# 2007-11-27  27294366  2.687719e+15             9859619       0.3612
# 2007-11-28   4581338  4.312765e+14             1453278       0.3172
# 2007-11-29   5124121  4.550658e+14             1069678       0.2088
# 2007-11-30   4609762  4.283257e+14             1260913       0.2735
# 2007-12-03   2977470  2.875200e+14              816123       0.2741

# %%
print(df.describe());
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  3322.000000  3322.000000  3322.000000  3322.000000  3322.000000
# mean    344.114314   344.763019   351.608007   337.531969   344.239539
# std     192.936882   193.619992   198.617808   188.676614   193.187813
# min     108.000000   108.000000   110.450000   105.650000   108.000000
# 25%     164.312500   164.850000   168.000000   161.600000   164.075000
# 50%     324.700000   325.750000   331.275000   319.850000   325.000000
# 75%     400.912500   401.000000   407.187500   395.000000   400.912500
# max    1307.450000  1310.250000  1324.000000  1270.000000  1308.000000
#
#              Close         VWAP        Volume      Turnover  \
# count  3322.000000  3322.000000  3.322000e+03  3.322000e+03
# mean    344.201626   344.853182  2.954564e+06  1.070144e+14
# std     193.045886   193.841305  4.104227e+06  2.625564e+14
# min     108.000000   108.340000  1.236600e+04  2.415857e+11
# 25%     164.312500   164.855000  7.493682e+05  1.817650e+13
# 50%     324.700000   325.765000  2.007292e+06  5.836041e+13
# 75%     400.912500   400.607500  3.636883e+06  1.158526e+14
# max    1307.450000  1302.150000  9.771788e+07  8.160988e+15
#
#        Deliverable Volume  %Deliverble
# count        3.322000e+03  3322.000000
# mean         1.207441e+06     0.445899
# std          1.398640e+06     0.160496
# min          5.383000e+03     0.067000
# 25%          3.212005e+05     0.332900
# 50%          8.132775e+05     0.445650
# 75%          1.605528e+06     0.555850
# max          2.241652e+07     0.979800

# %%
print(df);
# Out:
#             Prev Close    Open     High     Low   Last   Close    VWAP  \
# Date
# 2007-11-27      440.00  770.00  1050.00  770.00  959.0  962.90  984.72
# 2007-11-28      962.90  984.00   990.00  874.00  885.0  893.90  941.38
# 2007-11-29      893.90  909.00   914.75  841.00  887.0  884.20  888.09
# 2007-11-30      884.20  890.00   958.00  890.00  929.0  921.55  929.17
# 2007-12-03      921.55  939.75   995.00  922.00  980.0  969.30  965.65
# ...                ...     ...      ...     ...    ...     ...     ...
# 2021-04-26      725.35  733.00   739.65  728.90  729.2  730.75  733.25
# 2021-04-27      730.75  735.00   757.50  727.35  748.6  749.15  747.67
# 2021-04-28      749.15  755.00   760.00  741.10  743.4  746.25  751.02
# 2021-04-29      746.25  753.20   765.85  743.40  746.4  746.75  753.06
# 2021-04-30      746.75  739.00   759.45  724.50  726.4  730.05  743.35
#
#               Volume      Turnover  Deliverable Volume  %Deliverble
# Date
# 2007-11-27  27294366  2.687719e+15             9859619       0.3612
# 2007-11-28   4581338  4.312765e+14             1453278       0.3172
# 2007-11-29   5124121  4.550658e+14             1069678       0.2088
# 2007-11-30   4609762  4.283257e+14             1260913       0.2735
# 2007-12-03   2977470  2.875200e+14              816123       0.2741
# ...              ...           ...                 ...          ...
# 2021-04-26   9390549  6.885658e+14              838079       0.0892
# 2021-04-27  20573107  1.538191e+15             1779639       0.0865
# 2021-04-28  11156977  8.379106e+14             1342353       0.1203
# 2021-04-29  13851910  1.043139e+15             1304895       0.0942
# 2021-04-30  12600934  9.366911e+14             3514692       0.2789
#
# [3322 rows x 11 columns]

# %%
# function for box plot
def plot_boxplot(data, column):
    sns.boxplot(data=data, x=column);
    sns.despine();
    plt.title(f"Boxplot of {column}");
    plt.show();
    
# Define function to plot correlation heatmap
def plot_heatmap(data, title):
    sns.heatmap(data.corr(), cmap='coolwarm', annot=True);
    plt.title(title);
    sns.despine();
    plt.show();

# function for plot pair plot
def plot_pairplot(data, columns):
    sns.pairplot(data=data, vars=columns);
    sns.despine();
    plt.show();

def plot_timeSeries(dataframe, columns):
    for column in columns: 
        plt.figure(figsize=(16, 4));
        plt.plot(dataframe[column]);
        plt.title(f'{column} of Adani ports stock data');
        plt.ylabel(f"{column}");
        plt.xlabel('Trading Year');
        plt.grid(False);
        plt.show();

# %%
# All the data relate to stock price
priceData = ['Prev Close', 'Open', 'High', 'Low', 'Close', 'VWAP'];

# All the data relate to stock volume
volumeData = ['Volume', 'Turnover', 'Deliverable Volume', '%Deliverble'];

# Normalize data 
All_Columns = priceData + volumeData;

# %%
# Loop through each column to plot boxplots 
for column in All_Columns: 
    plot_boxplot(df, column);

# %%
# For price data
plot_pairplot(df, priceData);

# %%
# For volume data
plot_pairplot(df, volumeData);

# %%
plot_heatmap(df.iloc[:,1:], 'Relation Between Column');

# %%
# print all data time series
plot_timeSeries(df, All_Columns);

# %%
# Scaling the data based on highest and lowest value
scaler = MinMaxScaler();
scaled_data = scaler.fit_transform(df[All_Columns]);
scaled_df = pd.DataFrame(scaled_data, columns=All_Columns, index=df.index);
print(scaled_df.head());
# Out:
#             Prev Close      Open      High       Low     Close      VWAP  \
# Date
# 2007-11-27    0.276794  0.550634  0.774216  0.570576  0.712743  0.734103
# 2007-11-28    0.712743  0.728634  0.724774  0.659896  0.655217  0.697799
# 2007-11-29    0.655217  0.666251  0.662766  0.631554  0.647130  0.653161
# 2007-11-30    0.647130  0.650447  0.698406  0.673638  0.678269  0.687572
# 2007-12-03    0.678269  0.691828  0.728895  0.701121  0.718079  0.718129
#
#               Volume  Turnover  Deliverable Volume  %Deliverble
# Date
# 2007-11-27  0.279227  0.329318            0.439703     0.322305
# 2007-11-28  0.046763  0.052818            0.064606     0.274102
# 2007-11-29  0.052318  0.055733            0.047490     0.155346
# 2007-11-30  0.047054  0.052456            0.056023     0.226227
# 2007-12-03  0.030347  0.035202            0.036176     0.226884

# %%
# Function to labeling data
def create_sequences(data, seq_length):
    sequences = []
    labels = []
    for i in range(len(data)- seq_length):
        sequences.append(data[i:i + seq_length]);
        labels.append(data[i + seq_length]);
    return np.array(sequences), np.array(labels);

# To scaling the data with MinMaxScalerA
def inverse_transform_predictions(predictions): 
    return scaler.inverse_transform(predictions);

# Print the top 5 rows predictions data  
def print_shape_result(df):
    print("Predicted Results:");
    print(predictions_df.head());
    print(predictions_df.shape);

#It used to print Time Series plot with predict dataframe and actual dataframe
def time_series_plot(Model, column, predictDF):
    # these part are used to combine actual data and predict data
    comparison_df = pd.DataFrame({ 
        'Actual': actual_last_20[column].values, 
        'Predicted': predictDF[column].values 
    }, index=actual_last_20.index);
    
    # Plot actual and predicted values
    plot_time_series(comparison_df['Actual'], comparison_df['Predicted'], f"{column} - Actual vs Predicted ({Model})");

# Plot actual and predicted values
def plot_time_series(actual_series, predicted_series, title): 
    plt.figure(figsize=(16, 6));
    plt.plot(actual_series.index, actual_series, label='Actual');
    plt.plot(predicted_series.index, predicted_series, linestyle='--', label='Predicted');
    plt.title(title);
    plt.xlabel('Date');
    plt.ylabel('Value');
    plt.legend(loc='best');
    plt.grid(True);
    plt.show();

def plot_time_series_all(actual_series, model_data_map, column, best_model_name):
    plt.figure(figsize=(16, 6))
    plt.plot(actual_series.index, actual_series, label='Actual', color='black')
    
    for model_name, model_series in model_data_map.items():
        if model_name == best_model_name:
            plt.plot(model_series.index, model_series, linestyle='--', linewidth=2.5, label=f'{model_name} (Best)', color='red')
        else:
            plt.plot(model_series.index, model_series, linestyle='--', alpha=0.5, label=model_name)
    
    plt.title(f"{column} - Actual vs Predicted (Best: {best_model_name})")
    plt.xlabel('Date')
    plt.ylabel('Value')
    plt.legend(loc='best')
    plt.grid(True)
    plt.show()

    plt.show();

# %%
# Define sequence length 
seq_length = 60;

# Create sequences 
sequences, labels = create_sequences(scaled_df.values, seq_length);

# %%
# Split data as 80 for training/20 for testing
num_training_samples = int(0.8 * len(sequences));
X_train, X_test = sequences[:num_training_samples], sequences[num_training_samples:];
y_train, y_test = labels[:num_training_samples], sequences[num_training_samples:];

print(f"Training sequences shape: {X_train.shape}");
print(f"Training labels shape: {y_train.shape}");
print(f"Testing sequences shape: {X_test.shape}");
print(f"Testing labels shape: {y_test.shape}")
# Out:
# Training sequences shape: (2609, 60, 10)
# Training labels shape: (2609, 10)
# Testing sequences shape: (653, 60, 10)
# Testing labels shape: (653, 60, 10)

# %%
# Capture last 20% of data for compare the predict result 
num_samples = len(X_test)
actual_last_20 = df.iloc[-num_samples: -1]

# Callbacks defination
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True);

# %%
# Using LSTM(Long Short Term Model);alogrithm to predict
model = Sequential();
model.add(Input(shape=(seq_length, len(All_Columns))));
model.add(LSTM(100, return_sequences=True, kernel_regularizer='l2'));
model.add(Dropout(0.3));
model.add(LSTM(100, kernel_regularizer='l2'));
model.add(Dropout(0.3));
model.add(Dense(len(All_Columns)));
optimizer = Adam(learning_rate=0.001);

#Compile and fit the model
model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae', RootMeanSquaredError()]);
model.fit(X_train, y_train, epochs=200, batch_size=32, validation_split=0.2, callbacks=[early_stopping]);
# Out:
# Epoch 1/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 1.2225 - mae: 0.0825 - root_mean_squared_error: 0.1266 - val_loss: 0.2157 - val_mae: 0.0291 - val_root_mean_squared_error: 0.0557
# Epoch 2/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.1360 - mae: 0.0509 - root_mean_squared_error: 0.0789 - val_loss: 0.0188 - val_mae: 0.0338 - val_root_mean_squared_error: 0.0605
# Epoch 3/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0161 - mae: 0.0519 - root_mean_squared_error: 0.0834 - val_loss: 0.0057 - val_mae: 0.0415 - val_root_mean_squared_error: 0.0643
# Epoch 4/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0065 - mae: 0.0442 - root_mean_squared_error: 0.0719 - val_loss: 0.0044 - val_mae: 0.0318 - val_root_mean_squared_error: 0.0597
# Epoch 5/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0067 - mae: 0.0454 - root_mean_squared_error: 0.0765 - val_loss: 0.0051 - val_mae: 0.0440 - val_root_mean_squared_error: 0.0658
# Epoch 6/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0062 - mae: 0.0445 - root_mean_squared_error: 0.0738 - val_loss: 0.0043 - val_mae: 0.0306 - val_root_mean_squared_error: 0.0596
# Epoch 7/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0058 - mae: 0.0426 - root_mean_squared_error: 0.0718 - val_loss: 0.0043 - val_mae: 0.0319 - val_root_mean_squared_error: 0.0603
# Epoch 8/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0055 - mae: 0.0408 - root_mean_squared_error: 0.0698 - val_loss: 0.0048 - val_mae: 0.0355 - val_root_mean_squared_error: 0.0646
# Epoch 9/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0054 - mae: 0.0412 - root_mean_squared_error: 0.0691 - val_loss: 0.0040 - val_mae: 0.0306 - val_root_mean_squared_error: 0.0593
# Epoch 10/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0060 - mae: 0.0435 - root_mean_squared_error: 0.0733 - val_loss: 0.0048 - val_mae: 0.0399 - val_root_mean_squared_error: 0.0642
# Epoch 11/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0057 - mae: 0.0405 - root_mean_squared_error: 0.0711 - val_loss: 0.0042 - val_mae: 0.0321 - val_root_mean_squared_error: 0.0603
# Epoch 12/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0052 - mae: 0.0388 - root_mean_squared_error: 0.0685 - val_loss: 0.0048 - val_mae: 0.0409 - val_root_mean_squared_error: 0.0648
# Epoch 13/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0053 - mae: 0.0398 - root_mean_squared_error: 0.0691 - val_loss: 0.0041 - val_mae: 0.0296 - val_root_mean_squared_error: 0.0596
# Epoch 14/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0053 - mae: 0.0388 - root_mean_squared_error: 0.0676 - val_loss: 0.0040 - val_mae: 0.0282 - val_root_mean_squared_error: 0.0583
# Epoch 15/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0061 - mae: 0.0431 - root_mean_squared_error: 0.0734 - val_loss: 0.0040 - val_mae: 0.0293 - val_root_mean_squared_error: 0.0587
# Epoch 16/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0052 - mae: 0.0382 - root_mean_squared_error: 0.0680 - val_loss: 0.0042 - val_mae: 0.0314 - val_root_mean_squared_error: 0.0600
# Epoch 17/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0053 - mae: 0.0389 - root_mean_squared_error: 0.0688 - val_loss: 0.0039 - val_mae: 0.0290 - val_root_mean_squared_error: 0.0587
# Epoch 18/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0053 - mae: 0.0372 - root_mean_squared_error: 0.0696 - val_loss: 0.0038 - val_mae: 0.0282 - val_root_mean_squared_error: 0.0583
# Epoch 19/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0054 - mae: 0.0402 - root_mean_squared_error: 0.0704 - val_loss: 0.0041 - val_mae: 0.0295 - val_root_mean_squared_error: 0.0599
# Epoch 20/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0050 - mae: 0.0360 - root_mean_squared_error: 0.0671 - val_loss: 0.0045 - val_mae: 0.0382 - val_root_mean_squared_error: 0.0639
# Epoch 21/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0049 - mae: 0.0371 - root_mean_squared_error: 0.0668 - val_loss: 0.0041 - val_mae: 0.0333 - val_root_mean_squared_error: 0.0603
# Epoch 22/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0052 - mae: 0.0391 - root_mean_squared_error: 0.0683 - val_loss: 0.0040 - val_mae: 0.0318 - val_root_mean_squared_error: 0.0598
# Epoch 23/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0050 - mae: 0.0360 - root_mean_squared_error: 0.0673 - val_loss: 0.0042 - val_mae: 0.0336 - val_root_mean_squared_error: 0.0617
# Epoch 24/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0051 - mae: 0.0392 - root_mean_squared_error: 0.0681 - val_loss: 0.0040 - val_mae: 0.0286 - val_root_mean_squared_error: 0.0596
# Epoch 25/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0047 - mae: 0.0355 - root_mean_squared_error: 0.0655 - val_loss: 0.0041 - val_mae: 0.0320 - val_root_mean_squared_error: 0.0607
# Epoch 26/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0047 - mae: 0.0355 - root_mean_squared_error: 0.0653 - val_loss: 0.0043 - val_mae: 0.0366 - val_root_mean_squared_error: 0.0621
# Epoch 27/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0049 - mae: 0.0361 - root_mean_squared_error: 0.0669 - val_loss: 0.0039 - val_mae: 0.0295 - val_root_mean_squared_error: 0.0596
# Epoch 28/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0055 - mae: 0.0408 - root_mean_squared_error: 0.0703 - val_loss: 0.0040 - val_mae: 0.0297 - val_root_mean_squared_error: 0.0600

# %%
# Make predictions and inverse transform 
predictions = model.predict(X_test);
predictions = inverse_transform_predictions(predictions);

# Convert predictions to DataFrame 
predictions_df = pd.DataFrame(predictions, columns=All_Columns, index=df.index[-len(predictions):]);
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step

# %%
# Print LSTM predict result
print_shape_result(predictions_df);
# Out:
# Predicted Results:
#             Prev Close        Open        High         Low       Close  \
# Date
# 2018-09-06  388.904175  390.923523  400.281219  383.040253  391.901184
# 2018-09-07  388.206390  390.228821  399.480743  382.318115  391.163452
# 2018-09-10  387.664978  389.691467  398.849182  381.750305  390.591003
# 2018-09-11  387.222656  389.255585  398.342316  381.286377  390.131683
# 2018-09-12  386.850220  388.889221  397.928619  380.897980  389.752167
#
#                   VWAP      Volume      Turnover  Deliverable Volume  \
# Date
# 2018-09-06  396.134705  2136281.00  8.456052e+13         1081009.375
# 2018-09-07  395.453369  2138686.00  8.431940e+13         1081418.500
# 2018-09-10  394.931793  2140703.00  8.412212e+13         1081729.625
# 2018-09-11  394.504578  2142490.00  8.398626e+13         1082203.500
# 2018-09-12  394.140625  2144115.75  8.390666e+13         1082852.000
#
#             %Deliverble
# Date
# 2018-09-06     0.440553
# 2018-09-07     0.440608
# 2018-09-10     0.440648
# 2018-09-11     0.440684
# 2018-09-12     0.440719
# (653, 10)

# %%
# Align predictions with actual data 
predicted_last_20 = pd.DataFrame(predictions[-num_samples: -1], columns=All_Columns, index=actual_last_20.index)

for columns in All_Columns:
    time_series_plot('LSTM', columns, predicted_last_20);

# %%
# Using RNN(Recurrent neural networks);model to predict 
RNNmodel = Sequential();
RNNmodel.add(Input(shape=(seq_length, len(All_Columns))));
RNNmodel.add(SimpleRNN(100, return_sequences=True))
RNNmodel.add(Dropout(0.3));
RNNmodel.add(SimpleRNN(100));
RNNmodel.add(Dropout(0.3));
RNNmodel.add(Dense(len(All_Columns)));
optimizer = Adam(learning_rate=0.001);

#Compile and fit the model
RNNmodel.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae', RootMeanSquaredError()]);
RNNmodel.fit(X_train, y_train, epochs=200, batch_size=32, validation_split=0.2, callbacks=[early_stopping]);
# Out:
# Epoch 1/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.2169 - mae: 0.3477 - root_mean_squared_error: 0.4548 - val_loss: 0.0072 - val_mae: 0.0652 - val_root_mean_squared_error: 0.0849
# Epoch 2/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0365 - mae: 0.1476 - root_mean_squared_error: 0.1907 - val_loss: 0.0037 - val_mae: 0.0411 - val_root_mean_squared_error: 0.0607
# Epoch 3/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0187 - mae: 0.1040 - root_mean_squared_error: 0.1367 - val_loss: 0.0033 - val_mae: 0.0377 - val_root_mean_squared_error: 0.0576
# Epoch 4/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0131 - mae: 0.0848 - root_mean_squared_error: 0.1143 - val_loss: 0.0027 - val_mae: 0.0291 - val_root_mean_squared_error: 0.0523
# Epoch 5/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0100 - mae: 0.0731 - root_mean_squared_error: 0.1002 - val_loss: 0.0025 - val_mae: 0.0263 - val_root_mean_squared_error: 0.0499
# Epoch 6/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0083 - mae: 0.0657 - root_mean_squared_error: 0.0911 - val_loss: 0.0025 - val_mae: 0.0268 - val_root_mean_squared_error: 0.0496
# Epoch 7/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0072 - mae: 0.0608 - root_mean_squared_error: 0.0848 - val_loss: 0.0025 - val_mae: 0.0269 - val_root_mean_squared_error: 0.0496
# Epoch 8/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0062 - mae: 0.0554 - root_mean_squared_error: 0.0789 - val_loss: 0.0024 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0489
# Epoch 9/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0061 - mae: 0.0538 - root_mean_squared_error: 0.0778 - val_loss: 0.0024 - val_mae: 0.0238 - val_root_mean_squared_error: 0.0494
# Epoch 10/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0055 - mae: 0.0506 - root_mean_squared_error: 0.0742 - val_loss: 0.0023 - val_mae: 0.0226 - val_root_mean_squared_error: 0.0479
# Epoch 11/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0048 - mae: 0.0466 - root_mean_squared_error: 0.0689 - val_loss: 0.0023 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0480
# Epoch 12/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0045 - mae: 0.0452 - root_mean_squared_error: 0.0674 - val_loss: 0.0025 - val_mae: 0.0283 - val_root_mean_squared_error: 0.0500
# Epoch 13/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0044 - mae: 0.0441 - root_mean_squared_error: 0.0662 - val_loss: 0.0023 - val_mae: 0.0228 - val_root_mean_squared_error: 0.0479
# Epoch 14/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0042 - mae: 0.0424 - root_mean_squared_error: 0.0645 - val_loss: 0.0025 - val_mae: 0.0273 - val_root_mean_squared_error: 0.0500
# Epoch 15/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0043 - mae: 0.0418 - root_mean_squared_error: 0.0653 - val_loss: 0.0023 - val_mae: 0.0249 - val_root_mean_squared_error: 0.0483
# Epoch 16/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0038 - mae: 0.0395 - root_mean_squared_error: 0.0613 - val_loss: 0.0024 - val_mae: 0.0259 - val_root_mean_squared_error: 0.0486
# Epoch 17/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0037 - mae: 0.0390 - root_mean_squared_error: 0.0607 - val_loss: 0.0023 - val_mae: 0.0220 - val_root_mean_squared_error: 0.0483
# Epoch 18/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0039 - mae: 0.0382 - root_mean_squared_error: 0.0621 - val_loss: 0.0022 - val_mae: 0.0213 - val_root_mean_squared_error: 0.0470
# Epoch 19/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0036 - mae: 0.0379 - root_mean_squared_error: 0.0603 - val_loss: 0.0022 - val_mae: 0.0220 - val_root_mean_squared_error: 0.0471
# Epoch 20/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0035 - mae: 0.0365 - root_mean_squared_error: 0.0588 - val_loss: 0.0023 - val_mae: 0.0220 - val_root_mean_squared_error: 0.0479
# Epoch 21/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0035 - mae: 0.0359 - root_mean_squared_error: 0.0594 - val_loss: 0.0022 - val_mae: 0.0208 - val_root_mean_squared_error: 0.0467
# Epoch 22/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0034 - mae: 0.0350 - root_mean_squared_error: 0.0583 - val_loss: 0.0022 - val_mae: 0.0210 - val_root_mean_squared_error: 0.0472
# Epoch 23/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0035 - mae: 0.0351 - root_mean_squared_error: 0.0589 - val_loss: 0.0023 - val_mae: 0.0226 - val_root_mean_squared_error: 0.0476
# Epoch 24/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0033 - mae: 0.0339 - root_mean_squared_error: 0.0570 - val_loss: 0.0023 - val_mae: 0.0225 - val_root_mean_squared_error: 0.0477
# Epoch 25/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0034 - mae: 0.0341 - root_mean_squared_error: 0.0584 - val_loss: 0.0022 - val_mae: 0.0208 - val_root_mean_squared_error: 0.0471
# Epoch 26/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0031 - mae: 0.0331 - root_mean_squared_error: 0.0559 - val_loss: 0.0023 - val_mae: 0.0214 - val_root_mean_squared_error: 0.0476
# Epoch 27/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0032 - mae: 0.0331 - root_mean_squared_error: 0.0569 - val_loss: 0.0023 - val_mae: 0.0221 - val_root_mean_squared_error: 0.0480
# Epoch 28/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0030 - mae: 0.0320 - root_mean_squared_error: 0.0547 - val_loss: 0.0023 - val_mae: 0.0218 - val_root_mean_squared_error: 0.0478
# Epoch 29/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0031 - mae: 0.0324 - root_mean_squared_error: 0.0557 - val_loss: 0.0023 - val_mae: 0.0213 - val_root_mean_squared_error: 0.0480
# Epoch 30/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0032 - mae: 0.0326 - root_mean_squared_error: 0.0562 - val_loss: 0.0022 - val_mae: 0.0203 - val_root_mean_squared_error: 0.0466
# Epoch 31/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0030 - mae: 0.0313 - root_mean_squared_error: 0.0549 - val_loss: 0.0022 - val_mae: 0.0199 - val_root_mean_squared_error: 0.0465
# Epoch 32/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0031 - mae: 0.0316 - root_mean_squared_error: 0.0556 - val_loss: 0.0023 - val_mae: 0.0219 - val_root_mean_squared_error: 0.0479
# Epoch 33/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0029 - mae: 0.0305 - root_mean_squared_error: 0.0539 - val_loss: 0.0022 - val_mae: 0.0228 - val_root_mean_squared_error: 0.0472
# Epoch 34/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0029 - mae: 0.0309 - root_mean_squared_error: 0.0540 - val_loss: 0.0022 - val_mae: 0.0208 - val_root_mean_squared_error: 0.0471
# Epoch 35/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0032 - mae: 0.0309 - root_mean_squared_error: 0.0561 - val_loss: 0.0024 - val_mae: 0.0213 - val_root_mean_squared_error: 0.0489
# Epoch 36/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0029 - mae: 0.0304 - root_mean_squared_error: 0.0537 - val_loss: 0.0022 - val_mae: 0.0201 - val_root_mean_squared_error: 0.0467
# Epoch 37/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0029 - mae: 0.0304 - root_mean_squared_error: 0.0534 - val_loss: 0.0022 - val_mae: 0.0202 - val_root_mean_squared_error: 0.0467
# Epoch 38/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0028 - mae: 0.0292 - root_mean_squared_error: 0.0530 - val_loss: 0.0022 - val_mae: 0.0203 - val_root_mean_squared_error: 0.0471
# Epoch 39/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0030 - mae: 0.0303 - root_mean_squared_error: 0.0549 - val_loss: 0.0022 - val_mae: 0.0211 - val_root_mean_squared_error: 0.0470
# Epoch 40/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0028 - mae: 0.0292 - root_mean_squared_error: 0.0526 - val_loss: 0.0022 - val_mae: 0.0210 - val_root_mean_squared_error: 0.0467
# Epoch 41/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0029 - mae: 0.0298 - root_mean_squared_error: 0.0541 - val_loss: 0.0023 - val_mae: 0.0208 - val_root_mean_squared_error: 0.0476

# %%
# Make predictions
RNNpredictions = RNNmodel.predict(X_test);
RNNpredictions = scaler.inverse_transform(RNNpredictions);

# Convert predictions to DataFrame 
predictions_df_RNN = pd.DataFrame(RNNpredictions, columns=All_Columns, index=df.index[-len(RNNpredictions):]);
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %%
# Print RNN predict result
print_shape_result(predictions_df_RNN);
# Out:
# Predicted Results:
#             Prev Close        Open        High         Low       Close  \
# Date
# 2018-09-06  388.904175  390.923523  400.281219  383.040253  391.901184
# 2018-09-07  388.206390  390.228821  399.480743  382.318115  391.163452
# 2018-09-10  387.664978  389.691467  398.849182  381.750305  390.591003
# 2018-09-11  387.222656  389.255585  398.342316  381.286377  390.131683
# 2018-09-12  386.850220  388.889221  397.928619  380.897980  389.752167
#
#                   VWAP      Volume      Turnover  Deliverable Volume  \
# Date
# 2018-09-06  396.134705  2136281.00  8.456052e+13         1081009.375
# 2018-09-07  395.453369  2138686.00  8.431940e+13         1081418.500
# 2018-09-10  394.931793  2140703.00  8.412212e+13         1081729.625
# 2018-09-11  394.504578  2142490.00  8.398626e+13         1082203.500
# 2018-09-12  394.140625  2144115.75  8.390666e+13         1082852.000
#
#             %Deliverble
# Date
# 2018-09-06     0.440553
# 2018-09-07     0.440608
# 2018-09-10     0.440648
# 2018-09-11     0.440684
# 2018-09-12     0.440719
# (653, 10)

# %%
# Align predictions with actual data 
predicted_last_20_RNN = pd.DataFrame(RNNpredictions[-num_samples: -1], columns=All_Columns, index=actual_last_20.index);

for columns in All_Columns:
    time_series_plot('RNN', columns, predicted_last_20_RNN);

# %%
# using CNN (Convolutional Neural Networks);alogrithm to predict
CNNmodel = Sequential();
CNNmodel.add(Input(shape=(seq_length, len(All_Columns))));
CNNmodel.add(Conv1D(filters=64, kernel_size=2, activation='relu'));
CNNmodel.add(MaxPooling1D(pool_size=2));
CNNmodel.add(Flatten());
CNNmodel.add(Dense(100, activation='relu'));
CNNmodel.add(Dropout(0.3))
CNNmodel.add(Dense(100, activation='relu'));
CNNmodel.add(Dropout(0.3));
CNNmodel.add(Dense(len(All_Columns)));
optimizer = Adam(learning_rate=0.001);

#Compile and fit the model
CNNmodel.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae', RootMeanSquaredError()]);
CNNmodel.fit(X_train, y_train, epochs=200, batch_size=32, validation_split=0.2, callbacks=[early_stopping]);
# Out:
# Epoch 1/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0218 - mae: 0.1011 - root_mean_squared_error: 0.1454 - val_loss: 0.0034 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0584
# Epoch 2/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0078 - mae: 0.0590 - root_mean_squared_error: 0.0882 - val_loss: 0.0034 - val_mae: 0.0335 - val_root_mean_squared_error: 0.0586
# Epoch 3/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0061 - mae: 0.0512 - root_mean_squared_error: 0.0782 - val_loss: 0.0034 - val_mae: 0.0322 - val_root_mean_squared_error: 0.0582
# Epoch 4/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0061 - mae: 0.0495 - root_mean_squared_error: 0.0782 - val_loss: 0.0033 - val_mae: 0.0299 - val_root_mean_squared_error: 0.0573
# Epoch 5/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0052 - mae: 0.0455 - root_mean_squared_error: 0.0723 - val_loss: 0.0029 - val_mae: 0.0277 - val_root_mean_squared_error: 0.0540
# Epoch 6/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0049 - mae: 0.0438 - root_mean_squared_error: 0.0703 - val_loss: 0.0034 - val_mae: 0.0311 - val_root_mean_squared_error: 0.0580
# Epoch 7/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - mae: 0.0414 - root_mean_squared_error: 0.0675 - val_loss: 0.0029 - val_mae: 0.0275 - val_root_mean_squared_error: 0.0542
# Epoch 8/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0041 - mae: 0.0389 - root_mean_squared_error: 0.0643 - val_loss: 0.0029 - val_mae: 0.0263 - val_root_mean_squared_error: 0.0535
# Epoch 9/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - mae: 0.0386 - root_mean_squared_error: 0.0635 - val_loss: 0.0029 - val_mae: 0.0293 - val_root_mean_squared_error: 0.0543
# Epoch 10/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0037 - mae: 0.0364 - root_mean_squared_error: 0.0610 - val_loss: 0.0030 - val_mae: 0.0284 - val_root_mean_squared_error: 0.0548
# Epoch 11/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mae: 0.0358 - root_mean_squared_error: 0.0602 - val_loss: 0.0032 - val_mae: 0.0342 - val_root_mean_squared_error: 0.0568
# Epoch 12/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0038 - mae: 0.0358 - root_mean_squared_error: 0.0612 - val_loss: 0.0030 - val_mae: 0.0304 - val_root_mean_squared_error: 0.0549
# Epoch 13/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0344 - root_mean_squared_error: 0.0578 - val_loss: 0.0035 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0590
# Epoch 14/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0036 - mae: 0.0349 - root_mean_squared_error: 0.0601 - val_loss: 0.0032 - val_mae: 0.0324 - val_root_mean_squared_error: 0.0565
# Epoch 15/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mae: 0.0345 - root_mean_squared_error: 0.0583 - val_loss: 0.0032 - val_mae: 0.0301 - val_root_mean_squared_error: 0.0567
# Epoch 16/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0337 - root_mean_squared_error: 0.0572 - val_loss: 0.0030 - val_mae: 0.0297 - val_root_mean_squared_error: 0.0551
# Epoch 17/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0335 - root_mean_squared_error: 0.0573 - val_loss: 0.0031 - val_mae: 0.0314 - val_root_mean_squared_error: 0.0559
# Epoch 18/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0331 - root_mean_squared_error: 0.0568 - val_loss: 0.0034 - val_mae: 0.0312 - val_root_mean_squared_error: 0.0583

# %%
# Make predictions
CNNpredictions = CNNmodel.predict(X_test);
CNNpredictions = scaler.inverse_transform(CNNpredictions);

# Convert predictions to DataFrame 
predictions_df_CNN = pd.DataFrame(CNNpredictions, columns=All_Columns, index=df.index[-len(CNNpredictions):]);
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
# Print RNN predict result
print_shape_result(predictions_df_CNN);
# Out:
# Predicted Results:
#             Prev Close        Open        High         Low       Close  \
# Date
# 2018-09-06  388.904175  390.923523  400.281219  383.040253  391.901184
# 2018-09-07  388.206390  390.228821  399.480743  382.318115  391.163452
# 2018-09-10  387.664978  389.691467  398.849182  381.750305  390.591003
# 2018-09-11  387.222656  389.255585  398.342316  381.286377  390.131683
# 2018-09-12  386.850220  388.889221  397.928619  380.897980  389.752167
#
#                   VWAP      Volume      Turnover  Deliverable Volume  \
# Date
# 2018-09-06  396.134705  2136281.00  8.456052e+13         1081009.375
# 2018-09-07  395.453369  2138686.00  8.431940e+13         1081418.500
# 2018-09-10  394.931793  2140703.00  8.412212e+13         1081729.625
# 2018-09-11  394.504578  2142490.00  8.398626e+13         1082203.500
# 2018-09-12  394.140625  2144115.75  8.390666e+13         1082852.000
#
#             %Deliverble
# Date
# 2018-09-06     0.440553
# 2018-09-07     0.440608
# 2018-09-10     0.440648
# 2018-09-11     0.440684
# 2018-09-12     0.440719
# (653, 10)

# %%
# Correct the slicing to include the last element
predicted_last_20_CNN = pd.DataFrame(CNNpredictions[-num_samples: -1], columns=All_Columns, index=actual_last_20.index);

# Print all the columns data with time series plot about the CNN result
for columns in All_Columns:
    time_series_plot('CNN', columns, predicted_last_20_CNN);

# %%
actual_df = actual_last_20;
models = ["LSTM", "RNN", "CNN"]

DataFrameMap = {
    "Actual" : actual_df[All_Columns],
    "LSTM" : predictions_df[All_Columns],
    "RNN" : predictions_df_RNN[All_Columns],
    "CNN" : predictions_df_CNN[All_Columns]
}

def compute_scores(dataMap, metric="MAE"): 
    scores = {} 
    for column in All_Columns: 
        actual_series = dataMap["Actual"][column] 
        for model_name, model_df in dataMap.items(): 
            if model_name != "Actual": 
                predict_series = model_df[column] 
                predict_series_aligned, actual_series_aligned = predict_series.align(actual_series, join='inner') 
                
                if metric == "MAE": 
                    scores[(column, model_name)] = mean_absolute_error(actual_series_aligned, predict_series_aligned) 
                elif metric == "RMSE": 
                    mse = mean_squared_error(actual_series_aligned, predict_series_aligned) 
                    scores[(column, model_name)] = np.sqrt(mse) 
    return scores

def display_min_score(dataMap, score):
    data = {column: [score[(column, model)] for model in dataMap if model != "Actual"] for column in All_Columns} 
    df = pd.DataFrame(data, index=[m for m in dataMap if m != "Actual"])
    
    # highlight the min MAE(MEAN Absolute error) value
    return df.style.highlight_min(axis=0, color="green").format("{:.3f}")

# %%
MAE_scores = compute_scores(DataFrameMap, "MAE")

display_min_score(DataFrameMap, MAE_scores)
# Out:
# <style type="text/css">
# #T_c4797_row1_col0, #T_c4797_row1_col1, #T_c4797_row1_col2, #T_c4797_row1_col3, #T_c4797_row1_col4, #T_c4797_row1_col5, #T_c4797_row1_col6, #T_c4797_row1_col7, #T_c4797_row1_col8, #T_c4797_row1_col9 {
#   background-color: green;
# }
# </style>
# <table id="T_c4797">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c4797_level0_col0" class="col_heading level0 col0" >Prev Close</th>
#       <th id="T_c4797_level0_col1" class="col_heading level0 col1" >Open</th>
#       <th id="T_c4797_level0_col2" class="col_heading level0 col2" >High</th>
#       <th id="T_c4797_level0_col3" class="col_heading level0 col3" >Low</th>
#       <th id="T_c4797_level0_col4" class="col_heading level0 col4" >Close</th>
#       <th id="T_c4797_level0_col5" class="col_heading level0 col5" >VWAP</th>
#       <th id="T_c4797_level0_col6" class="col_heading level0 col6" >Volume</th>
#       <th id="T_c4797_level0_col7" class="col_heading level0 col7" >Turnover</th>
#       <th id="T_c4797_level0_col8" class="col_heading level0 col8" >Deliverable Volume</th>
#       <th id="T_c4797_level0_col9" class="col_heading level0 col9" >%Deliverble</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c4797_level0_row0" class="row_heading level0 row0" >LSTM</th>
#       <td id="T_c4797_row0_col0" class="data row0 col0" >25.593</td>
#       <td id="T_c4797_row0_col1" class="data row0 col1" >25.772</td>
#       <td id="T_c4797_row0_col2" class="data row0 col2" >27.476</td>
#       <td id="T_c4797_row0_col3" class="data row0 col3" >26.205</td>
#       <td id="T_c4797_row0_col4" class="data row0 col4" >26.776</td>
#       <td id="T_c4797_row0_col5" class="data row0 col5" >26.551</td>
#       <td id="T_c4797_row0_col6" class="data row0 col6" >3899412.419</td>
#       <td id="T_c4797_row0_col7" class="data row0 col7" >201227419635697.719</td>
#       <td id="T_c4797_row0_col8" class="data row0 col8" >930766.417</td>
#       <td id="T_c4797_row0_col9" class="data row0 col9" >0.156</td>
#     </tr>
#     <tr>
#       <th id="T_c4797_level0_row1" class="row_heading level0 row1" >RNN</th>
#       <td id="T_c4797_row1_col0" class="data row1 col0" >8.221</td>
#       <td id="T_c4797_row1_col1" class="data row1 col1" >9.700</td>
#       <td id="T_c4797_row1_col2" class="data row1 col2" >9.441</td>
#       <td id="T_c4797_row1_col3" class="data row1 col3" >11.736</td>
#       <td id="T_c4797_row1_col4" class="data row1 col4" >10.911</td>
#       <td id="T_c4797_row1_col5" class="data row1 col5" >9.847</td>
#       <td id="T_c4797_row1_col6" class="data row1 col6" >3141909.493</td>
#       <td id="T_c4797_row1_col7" class="data row1 col7" >192650770763308.156</td>
#       <td id="T_c4797_row1_col8" class="data row1 col8" >823663.060</td>
#       <td id="T_c4797_row1_col9" class="data row1 col9" >0.092</td>
#     </tr>
#     <tr>
#       <th id="T_c4797_level0_row2" class="row_heading level0 row2" >CNN</th>
#       <td id="T_c4797_row2_col0" class="data row2 col0" >32.943</td>
#       <td id="T_c4797_row2_col1" class="data row2 col1" >34.573</td>
#       <td id="T_c4797_row2_col2" class="data row2 col2" >33.888</td>
#       <td id="T_c4797_row2_col3" class="data row2 col3" >33.919</td>
#       <td id="T_c4797_row2_col4" class="data row2 col4" >35.617</td>
#       <td id="T_c4797_row2_col5" class="data row2 col5" >35.636</td>
#       <td id="T_c4797_row2_col6" class="data row2 col6" >4235056.179</td>
#       <td id="T_c4797_row2_col7" class="data row2 col7" >202317544566246.875</td>
#       <td id="T_c4797_row2_col8" class="data row2 col8" >911934.117</td>
#       <td id="T_c4797_row2_col9" class="data row2 col9" >0.115</td>
#     </tr>
#   </tbody>
# </table>

# %%
RMSE_scores = compute_scores(DataFrameMap, "RMSE")

display_min_score(DataFrameMap, RMSE_scores)
# Out:
# <style type="text/css">
# #T_d87f8_row1_col0, #T_d87f8_row1_col1, #T_d87f8_row1_col2, #T_d87f8_row1_col3, #T_d87f8_row1_col4, #T_d87f8_row1_col5, #T_d87f8_row1_col6, #T_d87f8_row1_col7, #T_d87f8_row1_col8, #T_d87f8_row1_col9 {
#   background-color: green;
# }
# </style>
# <table id="T_d87f8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d87f8_level0_col0" class="col_heading level0 col0" >Prev Close</th>
#       <th id="T_d87f8_level0_col1" class="col_heading level0 col1" >Open</th>
#       <th id="T_d87f8_level0_col2" class="col_heading level0 col2" >High</th>
#       <th id="T_d87f8_level0_col3" class="col_heading level0 col3" >Low</th>
#       <th id="T_d87f8_level0_col4" class="col_heading level0 col4" >Close</th>
#       <th id="T_d87f8_level0_col5" class="col_heading level0 col5" >VWAP</th>
#       <th id="T_d87f8_level0_col6" class="col_heading level0 col6" >Volume</th>
#       <th id="T_d87f8_level0_col7" class="col_heading level0 col7" >Turnover</th>
#       <th id="T_d87f8_level0_col8" class="col_heading level0 col8" >Deliverable Volume</th>
#       <th id="T_d87f8_level0_col9" class="col_heading level0 col9" >%Deliverble</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d87f8_level0_row0" class="row_heading level0 row0" >LSTM</th>
#       <td id="T_d87f8_row0_col0" class="data row0 col0" >38.197</td>
#       <td id="T_d87f8_row0_col1" class="data row0 col1" >38.548</td>
#       <td id="T_d87f8_row0_col2" class="data row0 col2" >40.091</td>
#       <td id="T_d87f8_row0_col3" class="data row0 col3" >38.245</td>
#       <td id="T_d87f8_row0_col4" class="data row0 col4" >38.783</td>
#       <td id="T_d87f8_row0_col5" class="data row0 col5" >38.077</td>
#       <td id="T_d87f8_row0_col6" class="data row0 col6" >8134096.727</td>
#       <td id="T_d87f8_row0_col7" class="data row0 col7" >561521898969111.000</td>
#       <td id="T_d87f8_row0_col8" class="data row0 col8" >1579581.823</td>
#       <td id="T_d87f8_row0_col9" class="data row0 col9" >0.185</td>
#     </tr>
#     <tr>
#       <th id="T_d87f8_level0_row1" class="row_heading level0 row1" >RNN</th>
#       <td id="T_d87f8_row1_col0" class="data row1 col0" >15.684</td>
#       <td id="T_d87f8_row1_col1" class="data row1 col1" >18.390</td>
#       <td id="T_d87f8_row1_col2" class="data row1 col2" >15.860</td>
#       <td id="T_d87f8_row1_col3" class="data row1 col3" >19.894</td>
#       <td id="T_d87f8_row1_col4" class="data row1 col4" >17.126</td>
#       <td id="T_d87f8_row1_col5" class="data row1 col5" >16.201</td>
#       <td id="T_d87f8_row1_col6" class="data row1 col6" >7195414.931</td>
#       <td id="T_d87f8_row1_col7" class="data row1 col7" >540440113639608.250</td>
#       <td id="T_d87f8_row1_col8" class="data row1 col8" >1398396.140</td>
#       <td id="T_d87f8_row1_col9" class="data row1 col9" >0.114</td>
#     </tr>
#     <tr>
#       <th id="T_d87f8_level0_row2" class="row_heading level0 row2" >CNN</th>
#       <td id="T_d87f8_row2_col0" class="data row2 col0" >53.754</td>
#       <td id="T_d87f8_row2_col1" class="data row2 col1" >55.829</td>
#       <td id="T_d87f8_row2_col2" class="data row2 col2" >54.848</td>
#       <td id="T_d87f8_row2_col3" class="data row2 col3" >55.710</td>
#       <td id="T_d87f8_row2_col4" class="data row2 col4" >59.073</td>
#       <td id="T_d87f8_row2_col5" class="data row2 col5" >58.641</td>
#       <td id="T_d87f8_row2_col6" class="data row2 col6" >8291461.298</td>
#       <td id="T_d87f8_row2_col7" class="data row2 col7" >557789913303206.625</td>
#       <td id="T_d87f8_row2_col8" class="data row2 col8" >1560542.216</td>
#       <td id="T_d87f8_row2_col9" class="data row2 col9" >0.137</td>
#     </tr>
#   </tbody>
# </table>

# %%
train, test = df[All_Columns].iloc[:num_training_samples], df[All_Columns].iloc[num_training_samples:] 

scaler = StandardScaler() 
train_scaled = pd.DataFrame(scaler.fit_transform(train), index=train.index, columns=train.columns) 
train_diff = train.diff().dropna() 
model = VAR(train_diff) 
model_fit = model.fit(maxlags=2)

lag_order = model_fit.k_ar 

input_data = train.values[-lag_order:] 
steps = len(test) 
VAR_forecast_diff = model_fit.forecast(y=input_data, steps=steps) 

VAR_forecast_diff = pd.DataFrame(VAR_forecast_diff, index=test.index, columns=All_Columns)
last_train = train.iloc[-1]
# Out:
# D:\Application\Anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
VAR_forecast_diff = model_fit.forecast(y=train_diff.values[-lag_order:], steps=len(actual_last_20)) 
VAR_forecast_cumsum = VAR_forecast_diff.cumsum(axis=0) 
VAR_forecast = VAR_forecast_cumsum + last_train.values 

predicted_last_20_VAR = pd.DataFrame(VAR_forecast, index=actual_last_20.index, columns=All_Columns) 
predicted_last_20_VAR.iloc[0] = last_train.values
print("Predictions:\n", predicted_last_20_VAR)
# Out:
# Predictions:
#              Prev Close        Open        High         Low       Close  \
# Date
# 2018-09-06  380.500000  384.000000  387.700000  380.100000  382.300000
# 2018-09-07  382.532892  384.467074  386.721422  379.062315  382.220711
# 2018-09-10  382.220711  383.199795  386.543159  379.194498  381.923040
# 2018-09-11  381.923041  383.101275  386.434436  378.867368  381.902498
# 2018-09-12  381.902498  383.322512  386.130467  378.739159  381.609265
# ...                ...         ...         ...         ...         ...
# 2021-04-23  249.338671  248.966903  242.736149  255.829983  249.132616
# 2021-04-26  249.132623  248.758347  242.513112  255.638860  248.926568
# 2021-04-27  248.926576  248.549790  242.290075  255.447737  248.720520
# 2021-04-28  248.720528  248.341234  242.067038  255.256613  248.514473
# 2021-04-29  248.514480  248.132678  241.844001  255.065490  248.308425
#
#                   VWAP        Volume      Turnover  Deliverable Volume  \
# Date
# 2018-09-06  384.760000  2.030226e+06  7.811538e+13       670564.000000
# 2018-09-07  383.508388  1.742562e+06  6.698140e+13       674350.665624
# 2018-09-10  383.423949  1.744201e+06  6.577231e+13       612763.030169
# 2018-09-11  383.272574  1.747793e+06  6.610595e+13       629627.034108
# 2018-09-12  382.994631  1.743973e+06  6.582059e+13       637190.602827
# ...                ...           ...           ...                 ...
# 2021-04-23  247.106521  7.801389e+05 -4.962935e+13       422084.600761
# 2021-04-26  246.895156  7.786415e+05 -4.980881e+13       421760.361284
# 2021-04-27  246.683791  7.771442e+05 -4.998827e+13       421436.121806
# 2021-04-28  246.472426  7.756468e+05 -5.016774e+13       421111.882329
# 2021-04-29  246.261061  7.741495e+05 -5.034720e+13       420787.642852
#
#             %Deliverble
# Date
# 2018-09-06     0.330300
# 2018-09-07     0.397207
# 2018-09-10     0.373526
# 2018-09-11     0.382049
# 2018-09-12     0.384008
# ...                 ...
# 2021-04-23     0.418924
# 2021-04-26     0.418982
# 2021-04-27     0.419039
# 2021-04-28     0.419097
# 2021-04-29     0.419155
#
# [652 rows x 10 columns]

# %%
for columns in All_Columns:
    time_series_plot('VAR', columns, predicted_last_20_VAR);

# %%
compareDataMap = {
    "Actual" : actual_df[All_Columns],
    "RNN": predictions_df_RNN[All_Columns],
    "VAR" : predicted_last_20_VAR[All_Columns]
}

compare_MAE_scores = compute_scores(compareDataMap, "MAE")

display_min_score(compareDataMap, compare_MAE_scores)
# Out:
# <style type="text/css">
# #T_820e0_row0_col0, #T_820e0_row0_col1, #T_820e0_row0_col2, #T_820e0_row0_col3, #T_820e0_row0_col4, #T_820e0_row0_col5, #T_820e0_row0_col6, #T_820e0_row0_col7, #T_820e0_row0_col8, #T_820e0_row0_col9 {
#   background-color: green;
# }
# </style>
# <table id="T_820e0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_820e0_level0_col0" class="col_heading level0 col0" >Prev Close</th>
#       <th id="T_820e0_level0_col1" class="col_heading level0 col1" >Open</th>
#       <th id="T_820e0_level0_col2" class="col_heading level0 col2" >High</th>
#       <th id="T_820e0_level0_col3" class="col_heading level0 col3" >Low</th>
#       <th id="T_820e0_level0_col4" class="col_heading level0 col4" >Close</th>
#       <th id="T_820e0_level0_col5" class="col_heading level0 col5" >VWAP</th>
#       <th id="T_820e0_level0_col6" class="col_heading level0 col6" >Volume</th>
#       <th id="T_820e0_level0_col7" class="col_heading level0 col7" >Turnover</th>
#       <th id="T_820e0_level0_col8" class="col_heading level0 col8" >Deliverable Volume</th>
#       <th id="T_820e0_level0_col9" class="col_heading level0 col9" >%Deliverble</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_820e0_level0_row0" class="row_heading level0 row0" >RNN</th>
#       <td id="T_820e0_row0_col0" class="data row0 col0" >8.221</td>
#       <td id="T_820e0_row0_col1" class="data row0 col1" >9.700</td>
#       <td id="T_820e0_row0_col2" class="data row0 col2" >9.441</td>
#       <td id="T_820e0_row0_col3" class="data row0 col3" >11.736</td>
#       <td id="T_820e0_row0_col4" class="data row0 col4" >10.911</td>
#       <td id="T_820e0_row0_col5" class="data row0 col5" >9.847</td>
#       <td id="T_820e0_row0_col6" class="data row0 col6" >3141909.493</td>
#       <td id="T_820e0_row0_col7" class="data row0 col7" >192650770763308.156</td>
#       <td id="T_820e0_row0_col8" class="data row0 col8" >823663.060</td>
#       <td id="T_820e0_row0_col9" class="data row0 col9" >0.092</td>
#     </tr>
#     <tr>
#       <th id="T_820e0_level0_row1" class="row_heading level0 row1" >VAR</th>
#       <td id="T_820e0_row1_col0" class="data row1 col0" >93.760</td>
#       <td id="T_820e0_row1_col1" class="data row1 col1" >94.602</td>
#       <td id="T_820e0_row1_col2" class="data row1 col2" >100.129</td>
#       <td id="T_820e0_row1_col3" class="data row1 col3" >88.685</td>
#       <td id="T_820e0_row1_col4" class="data row1 col4" >94.523</td>
#       <td id="T_820e0_row1_col5" class="data row1 col5" >95.233</td>
#       <td id="T_820e0_row1_col6" class="data row1 col6" >4575375.514</td>
#       <td id="T_820e0_row1_col7" class="data row1 col7" >268616564585373.062</td>
#       <td id="T_820e0_row1_col8" class="data row1 col8" >1109068.252</td>
#       <td id="T_820e0_row1_col9" class="data row1 col9" >0.136</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare_RMSE_scores = compute_scores(compareDataMap, "RMSE")

display_min_score(compareDataMap, compare_RMSE_scores)
# Out:
# <style type="text/css">
# #T_35777_row0_col0, #T_35777_row0_col1, #T_35777_row0_col2, #T_35777_row0_col3, #T_35777_row0_col4, #T_35777_row0_col5, #T_35777_row0_col6, #T_35777_row0_col7, #T_35777_row0_col8, #T_35777_row0_col9 {
#   background-color: green;
# }
# </style>
# <table id="T_35777">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35777_level0_col0" class="col_heading level0 col0" >Prev Close</th>
#       <th id="T_35777_level0_col1" class="col_heading level0 col1" >Open</th>
#       <th id="T_35777_level0_col2" class="col_heading level0 col2" >High</th>
#       <th id="T_35777_level0_col3" class="col_heading level0 col3" >Low</th>
#       <th id="T_35777_level0_col4" class="col_heading level0 col4" >Close</th>
#       <th id="T_35777_level0_col5" class="col_heading level0 col5" >VWAP</th>
#       <th id="T_35777_level0_col6" class="col_heading level0 col6" >Volume</th>
#       <th id="T_35777_level0_col7" class="col_heading level0 col7" >Turnover</th>
#       <th id="T_35777_level0_col8" class="col_heading level0 col8" >Deliverable Volume</th>
#       <th id="T_35777_level0_col9" class="col_heading level0 col9" >%Deliverble</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35777_level0_row0" class="row_heading level0 row0" >RNN</th>
#       <td id="T_35777_row0_col0" class="data row0 col0" >15.684</td>
#       <td id="T_35777_row0_col1" class="data row0 col1" >18.390</td>
#       <td id="T_35777_row0_col2" class="data row0 col2" >15.860</td>
#       <td id="T_35777_row0_col3" class="data row0 col3" >19.894</td>
#       <td id="T_35777_row0_col4" class="data row0 col4" >17.126</td>
#       <td id="T_35777_row0_col5" class="data row0 col5" >16.201</td>
#       <td id="T_35777_row0_col6" class="data row0 col6" >7195414.931</td>
#       <td id="T_35777_row0_col7" class="data row0 col7" >540440113639608.250</td>
#       <td id="T_35777_row0_col8" class="data row0 col8" >1398396.140</td>
#       <td id="T_35777_row0_col9" class="data row0 col9" >0.114</td>
#     </tr>
#     <tr>
#       <th id="T_35777_level0_row1" class="row_heading level0 row1" >VAR</th>
#       <td id="T_35777_row1_col0" class="data row1 col0" >153.629</td>
#       <td id="T_35777_row1_col1" class="data row1 col1" >154.869</td>
#       <td id="T_35777_row1_col2" class="data row1 col2" >163.220</td>
#       <td id="T_35777_row1_col3" class="data row1 col3" >146.290</td>
#       <td id="T_35777_row1_col4" class="data row1 col4" >154.864</td>
#       <td id="T_35777_row1_col5" class="data row1 col5" >155.827</td>
#       <td id="T_35777_row1_col6" class="data row1 col6" >8462672.289</td>
#       <td id="T_35777_row1_col7" class="data row1 col7" >606253654216960.875</td>
#       <td id="T_35777_row1_col8" class="data row1 col8" >1801414.105</td>
#       <td id="T_35777_row1_col9" class="data row1 col9" >0.163</td>
#     </tr>
#   </tbody>
# </table>

# %%
predictResults = [predicted_last_20, predicted_last_20_RNN, predicted_last_20_CNN, predicted_last_20_VAR];
path = "./PredictData/";
fileNames = ["LSTM_PredictResult_Stock.csv", "RNN_PredictResult_Stock.csv", "CNN_PredictResult_Stock.csv", "VAR_PredictResult_Stock.csv"]

for predictResult, fileName in zip(predictResults, fileNames):
    predictResult.to_csv(path + fileName, index="false");

# %%
metricsData = [MAE_scores, RMSE_scores, compare_MAE_scores, compare_RMSE_scores]
metricsFileNames = ["MAE_metrics.csv", "RMSE_metrics.csv", "MAE_Between_RNN_And_VAR.csv", "RMSE_Between_RNN_And_VAR.csv"]

for metricData, metricsFileName in zip(metricsData, metricsFileNames):
    df = pd.DataFrame.from_dict(metricData, orient="index", columns=["score"])
    
    if isinstance(next(iter(metricData.keys())), tuple):
        df.index = pd.MultiIndex.from_tuples(df.index, names=["Column", "Model"])
    
    df.to_csv(path + metricsFileName, index=True)
