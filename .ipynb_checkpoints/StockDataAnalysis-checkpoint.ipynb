# %%
### Notes
# Running this notebook may update or modify intermediate data files.  
#These changes do not affect the overall conclusions — evaluation consistently shows that the RNN model achieves the best performance among the tested approaches

# For data analysis and predictions
import numpy as np
import pandas as pd

# For preprocessing and error detection
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# For data Training (RNN, CNN, LSTM)
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, SimpleRNN, LSTM, Dense, Input, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import RootMeanSquaredError

# For Vector Auto Regression
from statsmodels.tsa.vector_ar.var_model import VAR

# For data visualize
import matplotlib.pyplot as plt
import seaborn as sns

# %%
csvData = pd.read_csv("./RawData/ADANIPORTS.csv", index_col=['Date'], parse_dates=['Date']);
df = pd.DataFrame(csvData);
df = df.drop(columns=['Trades', 'Series', 'Symbol']);

# %%
# display the columns in dataframe
print(df.columns);

# display how many data in csv file (row, column)
print(df.shape);
# Out:
# Index(['Prev Close', 'Open', 'High', 'Low', 'Last', 'Close', 'VWAP', 'Volume',
#        'Turnover', 'Deliverable Volume', '%Deliverble'],
#       dtype='str')
# (3322, 11)

# %%
# display the variable types of column
print(df.dtypes);
# Out:
# Prev Close            float64
# Open                  float64
# High                  float64
# Low                   float64
# Last                  float64
# Close                 float64
# VWAP                  float64
# Volume                  int64
# Turnover              float64
# Deliverable Volume      int64
# %Deliverble           float64
# dtype: object

# %%
print(df.head());
# Out:
#             Prev Close    Open     High    Low   Last   Close    VWAP  \
# Date
# 2007-11-27      440.00  770.00  1050.00  770.0  959.0  962.90  984.72
# 2007-11-28      962.90  984.00   990.00  874.0  885.0  893.90  941.38
# 2007-11-29      893.90  909.00   914.75  841.0  887.0  884.20  888.09
# 2007-11-30      884.20  890.00   958.00  890.0  929.0  921.55  929.17
# 2007-12-03      921.55  939.75   995.00  922.0  980.0  969.30  965.65
#
#               Volume      Turnover  Deliverable Volume  %Deliverble
# Date
# 2007-11-27  27294366  2.687719e+15             9859619       0.3612
# 2007-11-28   4581338  4.312765e+14             1453278       0.3172
# 2007-11-29   5124121  4.550658e+14             1069678       0.2088
# 2007-11-30   4609762  4.283257e+14             1260913       0.2735
# 2007-12-03   2977470  2.875200e+14              816123       0.2741

# %%
print(df.describe());
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  3322.000000  3322.000000  3322.000000  3322.000000  3322.000000
# mean    344.114314   344.763019   351.608007   337.531969   344.239539
# std     192.936882   193.619992   198.617808   188.676614   193.187813
# min     108.000000   108.000000   110.450000   105.650000   108.000000
# 25%     164.312500   164.850000   168.000000   161.600000   164.075000
# 50%     324.700000   325.750000   331.275000   319.850000   325.000000
# 75%     400.912500   401.000000   407.187500   395.000000   400.912500
# max    1307.450000  1310.250000  1324.000000  1270.000000  1308.000000
#
#              Close         VWAP        Volume      Turnover  \
# count  3322.000000  3322.000000  3.322000e+03  3.322000e+03
# mean    344.201626   344.853182  2.954564e+06  1.070144e+14
# std     193.045886   193.841305  4.104227e+06  2.625564e+14
# min     108.000000   108.340000  1.236600e+04  2.415857e+11
# 25%     164.312500   164.855000  7.493682e+05  1.817650e+13
# 50%     324.700000   325.765000  2.007292e+06  5.836041e+13
# 75%     400.912500   400.607500  3.636883e+06  1.158526e+14
# max    1307.450000  1302.150000  9.771788e+07  8.160988e+15
#
#        Deliverable Volume  %Deliverble
# count        3.322000e+03  3322.000000
# mean         1.207441e+06     0.445899
# std          1.398640e+06     0.160496
# min          5.383000e+03     0.067000
# 25%          3.212005e+05     0.332900
# 50%          8.132775e+05     0.445650
# 75%          1.605528e+06     0.555850
# max          2.241652e+07     0.979800

# %%
print(df);
# Out:
#             Prev Close    Open     High     Low   Last   Close    VWAP  \
# Date
# 2007-11-27      440.00  770.00  1050.00  770.00  959.0  962.90  984.72
# 2007-11-28      962.90  984.00   990.00  874.00  885.0  893.90  941.38
# 2007-11-29      893.90  909.00   914.75  841.00  887.0  884.20  888.09
# 2007-11-30      884.20  890.00   958.00  890.00  929.0  921.55  929.17
# 2007-12-03      921.55  939.75   995.00  922.00  980.0  969.30  965.65
# ...                ...     ...      ...     ...    ...     ...     ...
# 2021-04-26      725.35  733.00   739.65  728.90  729.2  730.75  733.25
# 2021-04-27      730.75  735.00   757.50  727.35  748.6  749.15  747.67
# 2021-04-28      749.15  755.00   760.00  741.10  743.4  746.25  751.02
# 2021-04-29      746.25  753.20   765.85  743.40  746.4  746.75  753.06
# 2021-04-30      746.75  739.00   759.45  724.50  726.4  730.05  743.35
#
#               Volume      Turnover  Deliverable Volume  %Deliverble
# Date
# 2007-11-27  27294366  2.687719e+15             9859619       0.3612
# 2007-11-28   4581338  4.312765e+14             1453278       0.3172
# 2007-11-29   5124121  4.550658e+14             1069678       0.2088
# 2007-11-30   4609762  4.283257e+14             1260913       0.2735
# 2007-12-03   2977470  2.875200e+14              816123       0.2741
# ...              ...           ...                 ...          ...
# 2021-04-26   9390549  6.885658e+14              838079       0.0892
# 2021-04-27  20573107  1.538191e+15             1779639       0.0865
# 2021-04-28  11156977  8.379106e+14             1342353       0.1203
# 2021-04-29  13851910  1.043139e+15             1304895       0.0942
# 2021-04-30  12600934  9.366911e+14             3514692       0.2789
#
# [3322 rows x 11 columns]

# %%
# function for box plot
def plot_boxplot(data, column):
    sns.boxplot(data=data, x=column);
    sns.despine();
    plt.title(f"Boxplot of {column}");
    plt.show();
    
# Define function to plot correlation heatmap
def plot_heatmap(data, title):
    sns.heatmap(data.corr(), cmap='coolwarm', annot=True);
    plt.title(title);
    sns.despine();
    plt.show();

# function for plot pair plot
def plot_pairplot(data, columns):
    sns.pairplot(data=data, vars=columns);
    sns.despine();
    plt.show();

def plot_timeSeries(dataframe, columns):
    for column in columns: 
        plt.figure(figsize=(16, 4));
        plt.plot(dataframe[column]);
        plt.title(f'{column} of Adani ports stock data');
        plt.ylabel(f"{column}");
        plt.xlabel('Trading Year');
        plt.grid(False);
        plt.show();

# %%
# All the data relate to stock price
priceData = ['Prev Close', 'Open', 'High', 'Low', 'Close', 'VWAP'];

# All the data relate to stock volume
volumeData = ['Volume', 'Turnover', 'Deliverable Volume', '%Deliverble'];

# Normalize data 
All_Columns = priceData + volumeData;

# %%
# Loop through each column to plot boxplots 
for column in All_Columns: 
    plot_boxplot(df, column);

# %%
# For price data
plot_pairplot(df, priceData);

# %%
# For volume data
plot_pairplot(df, volumeData);

# %%
plot_heatmap(df.iloc[:,1:], 'Relation Between Column');

# %%
# print all data time series
plot_timeSeries(df, All_Columns);

# %%
# Scaling the data based on highest and lowest value
scaler = MinMaxScaler();
scaled_data = scaler.fit_transform(df[All_Columns]);
scaled_df = pd.DataFrame(scaled_data, columns=All_Columns, index=df.index);
print(scaled_df.head());
# Out:
#             Prev Close      Open      High       Low     Close      VWAP  \
# Date
# 2007-11-27    0.276794  0.550634  0.774216  0.570576  0.712743  0.734103
# 2007-11-28    0.712743  0.728634  0.724774  0.659896  0.655217  0.697799
# 2007-11-29    0.655217  0.666251  0.662766  0.631554  0.647130  0.653161
# 2007-11-30    0.647130  0.650447  0.698406  0.673638  0.678269  0.687572
# 2007-12-03    0.678269  0.691828  0.728895  0.701121  0.718079  0.718129
#
#               Volume  Turnover  Deliverable Volume  %Deliverble
# Date
# 2007-11-27  0.279227  0.329318            0.439703     0.322305
# 2007-11-28  0.046763  0.052818            0.064606     0.274102
# 2007-11-29  0.052318  0.055733            0.047490     0.155346
# 2007-11-30  0.047054  0.052456            0.056023     0.226227
# 2007-12-03  0.030347  0.035202            0.036176     0.226884

# %%
# Function to labeling data
def create_sequences(data, seq_length):
    sequences = []
    labels = []
    for i in range(len(data)- seq_length):
        sequences.append(data[i:i + seq_length]);
        labels.append(data[i + seq_length]);
    return np.array(sequences), np.array(labels);

# To scaling the data with MinMaxScalerA
def inverse_transform_predictions(predictions): 
    return scaler.inverse_transform(predictions);

# Print the top 5 rows predictions data  
def print_shape_result(df):
    print("Predicted Results:");
    print(predictions_df.head());
    print(predictions_df.shape);

#It used to print Time Series plot with predict dataframe and actual dataframe
def time_series_plot(Model, column, predictDF):
    # these part are used to combine actual data and predict data
    comparison_df = pd.DataFrame({ 
        'Actual': actual_last_20[column].values, 
        'Predicted': predictDF[column].values 
    }, index=actual_last_20.index);
    
    # Plot actual and predicted values
    plot_time_series(comparison_df['Actual'], comparison_df['Predicted'], f"{column} - Actual vs Predicted ({Model})");

# Plot actual and predicted values
def plot_time_series(actual_series, predicted_series, title): 
    plt.figure(figsize=(16, 6));
    plt.plot(actual_series.index, actual_series, label='Actual');
    plt.plot(predicted_series.index, predicted_series, linestyle='--', label='Predicted');
    plt.title(title);
    plt.xlabel('Date');
    plt.ylabel('Value');
    plt.legend(loc='best');
    plt.grid(True);
    plt.show();

def plot_time_series_all(actual_series, model_data_map, column, best_model_name):
    plt.figure(figsize=(16, 6))
    plt.plot(actual_series.index, actual_series, label='Actual', color='black')
    
    for model_name, model_series in model_data_map.items():
        if model_name == best_model_name:
            plt.plot(model_series.index, model_series, linestyle='--', linewidth=2.5, label=f'{model_name} (Best)', color='red')
        else:
            plt.plot(model_series.index, model_series, linestyle='--', alpha=0.5, label=model_name)
    
    plt.title(f"{column} - Actual vs Predicted (Best: {best_model_name})")
    plt.xlabel('Date')
    plt.ylabel('Value')
    plt.legend(loc='best')
    plt.grid(True)
    plt.show()

    plt.show();

# %%
# Define sequence length 
seq_length = 60;

# Create sequences 
sequences, labels = create_sequences(scaled_df.values, seq_length);

# %%
# Split data as 80 for training/20 for testing
num_training_samples = int(0.8 * len(sequences));
X_train, X_test = sequences[:num_training_samples], sequences[num_training_samples:];
y_train, y_test = labels[:num_training_samples], sequences[num_training_samples:];

print(f"Training sequences shape: {X_train.shape}");
print(f"Training labels shape: {y_train.shape}");
print(f"Testing sequences shape: {X_test.shape}");
print(f"Testing labels shape: {y_test.shape}")
# Out:
# Training sequences shape: (2609, 60, 10)
# Training labels shape: (2609, 10)
# Testing sequences shape: (653, 60, 10)
# Testing labels shape: (653, 60, 10)

# %%
# Capture last 20% of data for compare the predict result 
num_samples = len(X_test)
actual_last_20 = df.iloc[-num_samples: -1]

# Callbacks defination
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True);

# %%
# Using LSTM(Long Short Term Model);alogrithm to predict
model = Sequential();
model.add(Input(shape=(seq_length, len(All_Columns))));
model.add(LSTM(100, return_sequences=True, kernel_regularizer='l2'));
model.add(Dropout(0.3));
model.add(LSTM(100, kernel_regularizer='l2'));
model.add(Dropout(0.3));
model.add(Dense(len(All_Columns)));
optimizer = Adam(learning_rate=0.001);

#Compile and fit the model
model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae', RootMeanSquaredError()]);
model.fit(X_train, y_train, epochs=200, batch_size=32, validation_split=0.2, callbacks=[early_stopping]);
# Out:
# Epoch 1/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 8s 88ms/step - loss: 0.8172 - mae: 0.0604 - root_mean_squared_error: 0.0941 - val_loss: 0.2187 - val_mae: 0.0308 - val_root_mean_squared_error: 0.0570
# Epoch 2/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 85ms/step - loss: 0.0867 - mae: 0.0498 - root_mean_squared_error: 0.0788 - val_loss: 0.0189 - val_mae: 0.0307 - val_root_mean_squared_error: 0.0579
# Epoch 3/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - loss: 0.0125 - mae: 0.0506 - root_mean_squared_error: 0.0804 - val_loss: 0.0056 - val_mae: 0.0299 - val_root_mean_squared_error: 0.0603
# Epoch 4/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 85ms/step - loss: 0.0073 - mae: 0.0482 - root_mean_squared_error: 0.0770 - val_loss: 0.0050 - val_mae: 0.0345 - val_root_mean_squared_error: 0.0618
# Epoch 5/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 89ms/step - loss: 0.0064 - mae: 0.0431 - root_mean_squared_error: 0.0737 - val_loss: 0.0044 - val_mae: 0.0322 - val_root_mean_squared_error: 0.0601
# Epoch 6/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 89ms/step - loss: 0.0060 - mae: 0.0420 - root_mean_squared_error: 0.0722 - val_loss: 0.0041 - val_mae: 0.0295 - val_root_mean_squared_error: 0.0589
# Epoch 7/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 87ms/step - loss: 0.0062 - mae: 0.0434 - root_mean_squared_error: 0.0738 - val_loss: 0.0045 - val_mae: 0.0324 - val_root_mean_squared_error: 0.0613
# Epoch 8/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 89ms/step - loss: 0.0058 - mae: 0.0420 - root_mean_squared_error: 0.0714 - val_loss: 0.0044 - val_mae: 0.0341 - val_root_mean_squared_error: 0.0607
# Epoch 9/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 89ms/step - loss: 0.0056 - mae: 0.0402 - root_mean_squared_error: 0.0703 - val_loss: 0.0046 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0635
# Epoch 10/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 87ms/step - loss: 0.0056 - mae: 0.0401 - root_mean_squared_error: 0.0706 - val_loss: 0.0045 - val_mae: 0.0345 - val_root_mean_squared_error: 0.0625
# Epoch 11/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 84ms/step - loss: 0.0056 - mae: 0.0405 - root_mean_squared_error: 0.0701 - val_loss: 0.0052 - val_mae: 0.0442 - val_root_mean_squared_error: 0.0668
# Epoch 12/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step - loss: 0.0055 - mae: 0.0395 - root_mean_squared_error: 0.0696 - val_loss: 0.0044 - val_mae: 0.0329 - val_root_mean_squared_error: 0.0622
# Epoch 13/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - loss: 0.0054 - mae: 0.0391 - root_mean_squared_error: 0.0694 - val_loss: 0.0045 - val_mae: 0.0345 - val_root_mean_squared_error: 0.0622
# Epoch 14/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 90ms/step - loss: 0.0054 - mae: 0.0383 - root_mean_squared_error: 0.0692 - val_loss: 0.0040 - val_mae: 0.0285 - val_root_mean_squared_error: 0.0589
# Epoch 15/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 91ms/step - loss: 0.0052 - mae: 0.0385 - root_mean_squared_error: 0.0688 - val_loss: 0.0043 - val_mae: 0.0334 - val_root_mean_squared_error: 0.0612
# Epoch 16/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 91ms/step - loss: 0.0051 - mae: 0.0378 - root_mean_squared_error: 0.0680 - val_loss: 0.0049 - val_mae: 0.0417 - val_root_mean_squared_error: 0.0663
# Epoch 17/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 90ms/step - loss: 0.0052 - mae: 0.0389 - root_mean_squared_error: 0.0687 - val_loss: 0.0042 - val_mae: 0.0336 - val_root_mean_squared_error: 0.0613
# Epoch 18/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step - loss: 0.0051 - mae: 0.0369 - root_mean_squared_error: 0.0674 - val_loss: 0.0046 - val_mae: 0.0387 - val_root_mean_squared_error: 0.0639
# Epoch 19/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 89ms/step - loss: 0.0050 - mae: 0.0376 - root_mean_squared_error: 0.0674 - val_loss: 0.0041 - val_mae: 0.0335 - val_root_mean_squared_error: 0.0605
# Epoch 20/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 89ms/step - loss: 0.0057 - mae: 0.0398 - root_mean_squared_error: 0.0705 - val_loss: 0.0040 - val_mae: 0.0295 - val_root_mean_squared_error: 0.0590
# Epoch 21/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 89ms/step - loss: 0.0051 - mae: 0.0375 - root_mean_squared_error: 0.0676 - val_loss: 0.0043 - val_mae: 0.0312 - val_root_mean_squared_error: 0.0610
# Epoch 22/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 89ms/step - loss: 0.0050 - mae: 0.0371 - root_mean_squared_error: 0.0672 - val_loss: 0.0041 - val_mae: 0.0323 - val_root_mean_squared_error: 0.0601
# Epoch 23/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step - loss: 0.0049 - mae: 0.0356 - root_mean_squared_error: 0.0664 - val_loss: 0.0040 - val_mae: 0.0308 - val_root_mean_squared_error: 0.0594
# Epoch 24/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 89ms/step - loss: 0.0048 - mae: 0.0359 - root_mean_squared_error: 0.0659 - val_loss: 0.0040 - val_mae: 0.0298 - val_root_mean_squared_error: 0.0597
# Epoch 25/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 89ms/step - loss: 0.0049 - mae: 0.0362 - root_mean_squared_error: 0.0668 - val_loss: 0.0049 - val_mae: 0.0424 - val_root_mean_squared_error: 0.0660
# Epoch 26/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step - loss: 0.0053 - mae: 0.0377 - root_mean_squared_error: 0.0686 - val_loss: 0.0041 - val_mae: 0.0295 - val_root_mean_squared_error: 0.0591
# Epoch 27/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 90ms/step - loss: 0.0051 - mae: 0.0363 - root_mean_squared_error: 0.0676 - val_loss: 0.0042 - val_mae: 0.0310 - val_root_mean_squared_error: 0.0600
# Epoch 28/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 89ms/step - loss: 0.0049 - mae: 0.0350 - root_mean_squared_error: 0.0658 - val_loss: 0.0043 - val_mae: 0.0337 - val_root_mean_squared_error: 0.0617
# Epoch 29/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 89ms/step - loss: 0.0049 - mae: 0.0355 - root_mean_squared_error: 0.0662 - val_loss: 0.0041 - val_mae: 0.0321 - val_root_mean_squared_error: 0.0603
# Epoch 30/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 89ms/step - loss: 0.0047 - mae: 0.0358 - root_mean_squared_error: 0.0652 - val_loss: 0.0043 - val_mae: 0.0335 - val_root_mean_squared_error: 0.0616
# Epoch 31/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 89ms/step - loss: 0.0048 - mae: 0.0355 - root_mean_squared_error: 0.0657 - val_loss: 0.0040 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0601
# Epoch 32/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 89ms/step - loss: 0.0047 - mae: 0.0345 - root_mean_squared_error: 0.0650 - val_loss: 0.0039 - val_mae: 0.0299 - val_root_mean_squared_error: 0.0591
# Epoch 33/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step - loss: 0.0046 - mae: 0.0339 - root_mean_squared_error: 0.0644 - val_loss: 0.0039 - val_mae: 0.0307 - val_root_mean_squared_error: 0.0596
# Epoch 34/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 92ms/step - loss: 0.0048 - mae: 0.0354 - root_mean_squared_error: 0.0661 - val_loss: 0.0040 - val_mae: 0.0305 - val_root_mean_squared_error: 0.0593
# Epoch 35/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 90ms/step - loss: 0.0047 - mae: 0.0347 - root_mean_squared_error: 0.0652 - val_loss: 0.0039 - val_mae: 0.0300 - val_root_mean_squared_error: 0.0593
# Epoch 36/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - loss: 0.0047 - mae: 0.0342 - root_mean_squared_error: 0.0650 - val_loss: 0.0043 - val_mae: 0.0357 - val_root_mean_squared_error: 0.0620
# Epoch 37/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - loss: 0.0047 - mae: 0.0351 - root_mean_squared_error: 0.0653 - val_loss: 0.0042 - val_mae: 0.0374 - val_root_mean_squared_error: 0.0620
# Epoch 38/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 90ms/step - loss: 0.0047 - mae: 0.0347 - root_mean_squared_error: 0.0650 - val_loss: 0.0041 - val_mae: 0.0314 - val_root_mean_squared_error: 0.0604
# Epoch 39/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step - loss: 0.0048 - mae: 0.0349 - root_mean_squared_error: 0.0649 - val_loss: 0.0040 - val_mae: 0.0305 - val_root_mean_squared_error: 0.0596
# Epoch 40/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - loss: 0.0046 - mae: 0.0347 - root_mean_squared_error: 0.0643 - val_loss: 0.0040 - val_mae: 0.0305 - val_root_mean_squared_error: 0.0599
# Epoch 41/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 0.0047 - mae: 0.0358 - root_mean_squared_error: 0.0652 - val_loss: 0.0042 - val_mae: 0.0330 - val_root_mean_squared_error: 0.0609
# Epoch 42/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - loss: 0.0045 - mae: 0.0331 - root_mean_squared_error: 0.0634 - val_loss: 0.0040 - val_mae: 0.0327 - val_root_mean_squared_error: 0.0601
# Epoch 43/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - loss: 0.0047 - mae: 0.0351 - root_mean_squared_error: 0.0650 - val_loss: 0.0042 - val_mae: 0.0348 - val_root_mean_squared_error: 0.0616
# Epoch 44/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 5s 77ms/step - loss: 0.0045 - mae: 0.0333 - root_mean_squared_error: 0.0640 - val_loss: 0.0043 - val_mae: 0.0335 - val_root_mean_squared_error: 0.0619
# Epoch 45/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 0.0045 - mae: 0.0341 - root_mean_squared_error: 0.0638 - val_loss: 0.0059 - val_mae: 0.0521 - val_root_mean_squared_error: 0.0736

# %%
# Make predictions and inverse transform 
predictions = model.predict(X_test);
predictions = inverse_transform_predictions(predictions);

# Convert predictions to DataFrame 
predictions_df = pd.DataFrame(predictions, columns=All_Columns, index=df.index[-len(predictions):]);
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step

# %%
# Print LSTM predict result
print_shape_result(predictions_df);
# Out:
# Predicted Results:
#             Prev Close        Open        High         Low       Close  \
# Date
# 2018-09-06  403.932617  401.954590  412.983032  393.488770  400.368866
# 2018-09-07  404.004211  402.020294  413.059723  393.534760  400.416046
# 2018-09-10  404.134399  402.153687  413.201294  393.649017  400.526062
# 2018-09-11  404.199188  402.235291  413.287781  393.717773  400.578400
# 2018-09-12  404.131104  402.196320  413.246613  393.673462  400.508148
#
#                   VWAP       Volume      Turnover  Deliverable Volume  \
# Date
# 2018-09-06  401.691803  1878668.750  5.018862e+13         936622.6250
# 2018-09-07  401.743713  1878541.875  5.019373e+13         936641.6875
# 2018-09-10  401.862213  1878366.125  5.019752e+13         936561.6250
# 2018-09-11  401.928375  1878640.125  5.020016e+13         936650.9375
# 2018-09-12  401.874481  1879588.125  5.020613e+13         937049.6875
#
#             %Deliverble
# Date
# 2018-09-06     0.438801
# 2018-09-07     0.438793
# 2018-09-10     0.438773
# 2018-09-11     0.438750
# 2018-09-12     0.438731
# (653, 10)

# %%
# Align predictions with actual data 
predicted_last_20 = pd.DataFrame(predictions[-num_samples: -1], columns=All_Columns, index=actual_last_20.index)

for columns in All_Columns:
    time_series_plot('LSTM', columns, predicted_last_20);

# %%
# Using RNN(Recurrent neural networks);model to predict 
RNNmodel = Sequential();
RNNmodel.add(Input(shape=(seq_length, len(All_Columns))));
RNNmodel.add(SimpleRNN(100, return_sequences=True))
RNNmodel.add(Dropout(0.3));
RNNmodel.add(SimpleRNN(100));
RNNmodel.add(Dropout(0.3));
RNNmodel.add(Dense(len(All_Columns)));
optimizer = Adam(learning_rate=0.001);

#Compile and fit the model
RNNmodel.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae', RootMeanSquaredError()]);
RNNmodel.fit(X_train, y_train, epochs=200, batch_size=32, validation_split=0.2, callbacks=[early_stopping]);
# Out:
# Epoch 1/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 0.1276 - mae: 0.2664 - root_mean_squared_error: 0.3573 - val_loss: 0.0060 - val_mae: 0.0576 - val_root_mean_squared_error: 0.0775
# Epoch 2/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0299 - mae: 0.1326 - root_mean_squared_error: 0.1730 - val_loss: 0.0036 - val_mae: 0.0390 - val_root_mean_squared_error: 0.0598
# Epoch 3/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0168 - mae: 0.0982 - root_mean_squared_error: 0.1296 - val_loss: 0.0027 - val_mae: 0.0310 - val_root_mean_squared_error: 0.0521
# Epoch 4/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0122 - mae: 0.0815 - root_mean_squared_error: 0.1105 - val_loss: 0.0028 - val_mae: 0.0304 - val_root_mean_squared_error: 0.0527
# Epoch 5/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0095 - mae: 0.0714 - root_mean_squared_error: 0.0975 - val_loss: 0.0024 - val_mae: 0.0268 - val_root_mean_squared_error: 0.0492
# Epoch 6/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0080 - mae: 0.0648 - root_mean_squared_error: 0.0896 - val_loss: 0.0023 - val_mae: 0.0242 - val_root_mean_squared_error: 0.0485
# Epoch 7/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0069 - mae: 0.0584 - root_mean_squared_error: 0.0829 - val_loss: 0.0024 - val_mae: 0.0248 - val_root_mean_squared_error: 0.0485
# Epoch 8/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0063 - mae: 0.0554 - root_mean_squared_error: 0.0796 - val_loss: 0.0024 - val_mae: 0.0255 - val_root_mean_squared_error: 0.0485
# Epoch 9/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0057 - mae: 0.0516 - root_mean_squared_error: 0.0753 - val_loss: 0.0023 - val_mae: 0.0229 - val_root_mean_squared_error: 0.0480
# Epoch 10/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0052 - mae: 0.0486 - root_mean_squared_error: 0.0719 - val_loss: 0.0023 - val_mae: 0.0221 - val_root_mean_squared_error: 0.0478
# Epoch 11/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0049 - mae: 0.0467 - root_mean_squared_error: 0.0699 - val_loss: 0.0023 - val_mae: 0.0221 - val_root_mean_squared_error: 0.0481
# Epoch 12/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0046 - mae: 0.0448 - root_mean_squared_error: 0.0679 - val_loss: 0.0025 - val_mae: 0.0235 - val_root_mean_squared_error: 0.0504
# Epoch 13/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0044 - mae: 0.0435 - root_mean_squared_error: 0.0664 - val_loss: 0.0024 - val_mae: 0.0230 - val_root_mean_squared_error: 0.0487
# Epoch 14/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0042 - mae: 0.0416 - root_mean_squared_error: 0.0647 - val_loss: 0.0023 - val_mae: 0.0228 - val_root_mean_squared_error: 0.0480
# Epoch 15/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0039 - mae: 0.0399 - root_mean_squared_error: 0.0623 - val_loss: 0.0022 - val_mae: 0.0225 - val_root_mean_squared_error: 0.0474
# Epoch 16/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0039 - mae: 0.0396 - root_mean_squared_error: 0.0623 - val_loss: 0.0023 - val_mae: 0.0216 - val_root_mean_squared_error: 0.0475
# Epoch 17/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0038 - mae: 0.0387 - root_mean_squared_error: 0.0615 - val_loss: 0.0023 - val_mae: 0.0228 - val_root_mean_squared_error: 0.0480
# Epoch 18/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0037 - mae: 0.0378 - root_mean_squared_error: 0.0610 - val_loss: 0.0023 - val_mae: 0.0210 - val_root_mean_squared_error: 0.0476
# Epoch 19/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0035 - mae: 0.0366 - root_mean_squared_error: 0.0594 - val_loss: 0.0023 - val_mae: 0.0216 - val_root_mean_squared_error: 0.0484
# Epoch 20/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0035 - mae: 0.0360 - root_mean_squared_error: 0.0593 - val_loss: 0.0023 - val_mae: 0.0218 - val_root_mean_squared_error: 0.0478
# Epoch 21/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0034 - mae: 0.0355 - root_mean_squared_error: 0.0585 - val_loss: 0.0024 - val_mae: 0.0224 - val_root_mean_squared_error: 0.0486
# Epoch 22/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0033 - mae: 0.0347 - root_mean_squared_error: 0.0577 - val_loss: 0.0022 - val_mae: 0.0201 - val_root_mean_squared_error: 0.0470
# Epoch 23/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0033 - mae: 0.0345 - root_mean_squared_error: 0.0578 - val_loss: 0.0023 - val_mae: 0.0207 - val_root_mean_squared_error: 0.0474
# Epoch 24/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0032 - mae: 0.0335 - root_mean_squared_error: 0.0566 - val_loss: 0.0023 - val_mae: 0.0220 - val_root_mean_squared_error: 0.0480
# Epoch 25/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0032 - mae: 0.0333 - root_mean_squared_error: 0.0566 - val_loss: 0.0022 - val_mae: 0.0202 - val_root_mean_squared_error: 0.0471
# Epoch 26/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0032 - mae: 0.0330 - root_mean_squared_error: 0.0563 - val_loss: 0.0022 - val_mae: 0.0205 - val_root_mean_squared_error: 0.0472
# Epoch 27/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0031 - mae: 0.0324 - root_mean_squared_error: 0.0553 - val_loss: 0.0022 - val_mae: 0.0211 - val_root_mean_squared_error: 0.0474
# Epoch 28/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0030 - mae: 0.0320 - root_mean_squared_error: 0.0549 - val_loss: 0.0023 - val_mae: 0.0216 - val_root_mean_squared_error: 0.0479
# Epoch 29/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0030 - mae: 0.0316 - root_mean_squared_error: 0.0546 - val_loss: 0.0022 - val_mae: 0.0210 - val_root_mean_squared_error: 0.0474
# Epoch 30/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0030 - mae: 0.0318 - root_mean_squared_error: 0.0552 - val_loss: 0.0023 - val_mae: 0.0216 - val_root_mean_squared_error: 0.0476
# Epoch 31/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0030 - mae: 0.0314 - root_mean_squared_error: 0.0546 - val_loss: 0.0022 - val_mae: 0.0214 - val_root_mean_squared_error: 0.0472
# Epoch 32/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0029 - mae: 0.0307 - root_mean_squared_error: 0.0540 - val_loss: 0.0024 - val_mae: 0.0216 - val_root_mean_squared_error: 0.0494

# %%
# Make predictions
RNNpredictions = RNNmodel.predict(X_test);
RNNpredictions = scaler.inverse_transform(RNNpredictions);

# Convert predictions to DataFrame 
predictions_df_RNN = pd.DataFrame(RNNpredictions, columns=All_Columns, index=df.index[-len(RNNpredictions):]);
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step

# %%
# Print RNN predict result
print_shape_result(predictions_df_RNN);
# Out:
# Predicted Results:
#             Prev Close        Open        High         Low       Close  \
# Date
# 2018-09-06  403.932617  401.954590  412.983032  393.488770  400.368866
# 2018-09-07  404.004211  402.020294  413.059723  393.534760  400.416046
# 2018-09-10  404.134399  402.153687  413.201294  393.649017  400.526062
# 2018-09-11  404.199188  402.235291  413.287781  393.717773  400.578400
# 2018-09-12  404.131104  402.196320  413.246613  393.673462  400.508148
#
#                   VWAP       Volume      Turnover  Deliverable Volume  \
# Date
# 2018-09-06  401.691803  1878668.750  5.018862e+13         936622.6250
# 2018-09-07  401.743713  1878541.875  5.019373e+13         936641.6875
# 2018-09-10  401.862213  1878366.125  5.019752e+13         936561.6250
# 2018-09-11  401.928375  1878640.125  5.020016e+13         936650.9375
# 2018-09-12  401.874481  1879588.125  5.020613e+13         937049.6875
#
#             %Deliverble
# Date
# 2018-09-06     0.438801
# 2018-09-07     0.438793
# 2018-09-10     0.438773
# 2018-09-11     0.438750
# 2018-09-12     0.438731
# (653, 10)

# %%
# Align predictions with actual data 
predicted_last_20_RNN = pd.DataFrame(RNNpredictions[-num_samples: -1], columns=All_Columns, index=actual_last_20.index);

for columns in All_Columns:
    time_series_plot('RNN', columns, predicted_last_20_RNN);

# %%
# using CNN (Convolutional Neural Networks);alogrithm to predict
CNNmodel = Sequential();
CNNmodel.add(Input(shape=(seq_length, len(All_Columns))));
CNNmodel.add(Conv1D(filters=64, kernel_size=2, activation='relu'));
CNNmodel.add(MaxPooling1D(pool_size=2));
CNNmodel.add(Flatten());
CNNmodel.add(Dense(100, activation='relu'));
CNNmodel.add(Dropout(0.3))
CNNmodel.add(Dense(100, activation='relu'));
CNNmodel.add(Dropout(0.3));
CNNmodel.add(Dense(len(All_Columns)));
optimizer = Adam(learning_rate=0.001);

#Compile and fit the model
CNNmodel.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae', RootMeanSquaredError()]);
CNNmodel.fit(X_train, y_train, epochs=200, batch_size=32, validation_split=0.2, callbacks=[early_stopping]);
# Out:
# Epoch 1/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0157 - mae: 0.0851 - root_mean_squared_error: 0.1253 - val_loss: 0.0034 - val_mae: 0.0329 - val_root_mean_squared_error: 0.0580
# Epoch 2/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0081 - mae: 0.0593 - root_mean_squared_error: 0.0898 - val_loss: 0.0041 - val_mae: 0.0359 - val_root_mean_squared_error: 0.0639
# Epoch 3/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0064 - mae: 0.0517 - root_mean_squared_error: 0.0801 - val_loss: 0.0033 - val_mae: 0.0327 - val_root_mean_squared_error: 0.0575
# Epoch 4/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0056 - mae: 0.0470 - root_mean_squared_error: 0.0747 - val_loss: 0.0032 - val_mae: 0.0306 - val_root_mean_squared_error: 0.0563
# Epoch 5/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0050 - mae: 0.0440 - root_mean_squared_error: 0.0709 - val_loss: 0.0033 - val_mae: 0.0317 - val_root_mean_squared_error: 0.0572
# Epoch 6/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0050 - mae: 0.0433 - root_mean_squared_error: 0.0709 - val_loss: 0.0041 - val_mae: 0.0428 - val_root_mean_squared_error: 0.0638
# Epoch 7/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0046 - mae: 0.0409 - root_mean_squared_error: 0.0680 - val_loss: 0.0030 - val_mae: 0.0305 - val_root_mean_squared_error: 0.0549
# Epoch 8/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0045 - mae: 0.0401 - root_mean_squared_error: 0.0667 - val_loss: 0.0029 - val_mae: 0.0286 - val_root_mean_squared_error: 0.0535
# Epoch 9/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0043 - mae: 0.0388 - root_mean_squared_error: 0.0657 - val_loss: 0.0029 - val_mae: 0.0292 - val_root_mean_squared_error: 0.0539
# Epoch 10/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0041 - mae: 0.0376 - root_mean_squared_error: 0.0644 - val_loss: 0.0031 - val_mae: 0.0322 - val_root_mean_squared_error: 0.0558

# %%
# Make predictions
CNNpredictions = CNNmodel.predict(X_test);
CNNpredictions = scaler.inverse_transform(CNNpredictions);

# Convert predictions to DataFrame 
predictions_df_CNN = pd.DataFrame(CNNpredictions, columns=All_Columns, index=df.index[-len(CNNpredictions):]);
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
# Print RNN predict result
print_shape_result(predictions_df_CNN);
# Out:
# Predicted Results:
#             Prev Close        Open        High         Low       Close  \
# Date
# 2018-09-06  403.932617  401.954590  412.983032  393.488770  400.368866
# 2018-09-07  404.004211  402.020294  413.059723  393.534760  400.416046
# 2018-09-10  404.134399  402.153687  413.201294  393.649017  400.526062
# 2018-09-11  404.199188  402.235291  413.287781  393.717773  400.578400
# 2018-09-12  404.131104  402.196320  413.246613  393.673462  400.508148
#
#                   VWAP       Volume      Turnover  Deliverable Volume  \
# Date
# 2018-09-06  401.691803  1878668.750  5.018862e+13         936622.6250
# 2018-09-07  401.743713  1878541.875  5.019373e+13         936641.6875
# 2018-09-10  401.862213  1878366.125  5.019752e+13         936561.6250
# 2018-09-11  401.928375  1878640.125  5.020016e+13         936650.9375
# 2018-09-12  401.874481  1879588.125  5.020613e+13         937049.6875
#
#             %Deliverble
# Date
# 2018-09-06     0.438801
# 2018-09-07     0.438793
# 2018-09-10     0.438773
# 2018-09-11     0.438750
# 2018-09-12     0.438731
# (653, 10)

# %%
# Correct the slicing to include the last element
predicted_last_20_CNN = pd.DataFrame(CNNpredictions[-num_samples: -1], columns=All_Columns, index=actual_last_20.index);

# Print all the columns data with time series plot about the CNN result
for columns in All_Columns:
    time_series_plot('CNN', columns, predicted_last_20_CNN);

# %%
actual_df = actual_last_20;
models = ["LSTM", "RNN", "CNN"]

DataFrameMap = {
    "Actual" : actual_df[All_Columns],
    "LSTM" : predictions_df[All_Columns],
    "RNN" : predictions_df_RNN[All_Columns],
    "CNN" : predictions_df_CNN[All_Columns]
}

def compute_scores(dataMap, metric="MAE"): 
    scores = {} 
    for column in All_Columns: 
        actual_series = dataMap["Actual"][column] 
        for model_name, model_df in dataMap.items(): 
            if model_name != "Actual": 
                predict_series = model_df[column] 
                predict_series_aligned, actual_series_aligned = predict_series.align(actual_series, join='inner') 
                
                if metric == "MAE": 
                    scores[(column, model_name)] = mean_absolute_error(actual_series_aligned, predict_series_aligned) 
                elif metric == "RMSE": 
                    mse = mean_squared_error(actual_series_aligned, predict_series_aligned)
                    ## rmse =  the square root of mse
                    scores[(column, model_name)] = np.sqrt(mse) 
    return scores

def display_min_score(dataMap, score):
    data = {column: [score[(column, model)] for model in dataMap if model != "Actual"] for column in All_Columns} 
    df = pd.DataFrame(data, index=[m for m in dataMap if m != "Actual"])
    
    # highlight the min MAE(MEAN Absolute error) value
    return df.style.highlight_min(axis=0, color="green").format("{:.3f}")

# %%
MAE_scores = compute_scores(DataFrameMap, "MAE")

display_min_score(DataFrameMap, MAE_scores)
# Out:
# <style type="text/css">
# #T_4f6f3_row1_col0, #T_4f6f3_row1_col1, #T_4f6f3_row1_col2, #T_4f6f3_row1_col3, #T_4f6f3_row1_col4, #T_4f6f3_row1_col5, #T_4f6f3_row1_col6, #T_4f6f3_row1_col7, #T_4f6f3_row1_col8, #T_4f6f3_row1_col9 {
#   background-color: green;
# }
# </style>
# <table id="T_4f6f3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f6f3_level0_col0" class="col_heading level0 col0" >Prev Close</th>
#       <th id="T_4f6f3_level0_col1" class="col_heading level0 col1" >Open</th>
#       <th id="T_4f6f3_level0_col2" class="col_heading level0 col2" >High</th>
#       <th id="T_4f6f3_level0_col3" class="col_heading level0 col3" >Low</th>
#       <th id="T_4f6f3_level0_col4" class="col_heading level0 col4" >Close</th>
#       <th id="T_4f6f3_level0_col5" class="col_heading level0 col5" >VWAP</th>
#       <th id="T_4f6f3_level0_col6" class="col_heading level0 col6" >Volume</th>
#       <th id="T_4f6f3_level0_col7" class="col_heading level0 col7" >Turnover</th>
#       <th id="T_4f6f3_level0_col8" class="col_heading level0 col8" >Deliverable Volume</th>
#       <th id="T_4f6f3_level0_col9" class="col_heading level0 col9" >%Deliverble</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f6f3_level0_row0" class="row_heading level0 row0" >LSTM</th>
#       <td id="T_4f6f3_row0_col0" class="data row0 col0" >26.119</td>
#       <td id="T_4f6f3_row0_col1" class="data row0 col1" >25.998</td>
#       <td id="T_4f6f3_row0_col2" class="data row0 col2" >28.698</td>
#       <td id="T_4f6f3_row0_col3" class="data row0 col3" >25.439</td>
#       <td id="T_4f6f3_row0_col4" class="data row0 col4" >26.397</td>
#       <td id="T_4f6f3_row0_col5" class="data row0 col5" >26.406</td>
#       <td id="T_4f6f3_row0_col6" class="data row0 col6" >4111103.250</td>
#       <td id="T_4f6f3_row0_col7" class="data row0 col7" >228723576212215.656</td>
#       <td id="T_4f6f3_row0_col8" class="data row0 col8" >985069.125</td>
#       <td id="T_4f6f3_row0_col9" class="data row0 col9" >0.157</td>
#     </tr>
#     <tr>
#       <th id="T_4f6f3_level0_row1" class="row_heading level0 row1" >RNN</th>
#       <td id="T_4f6f3_row1_col0" class="data row1 col0" >12.273</td>
#       <td id="T_4f6f3_row1_col1" class="data row1 col1" >9.161</td>
#       <td id="T_4f6f3_row1_col2" class="data row1 col2" >11.210</td>
#       <td id="T_4f6f3_row1_col3" class="data row1 col3" >10.365</td>
#       <td id="T_4f6f3_row1_col4" class="data row1 col4" >11.628</td>
#       <td id="T_4f6f3_row1_col5" class="data row1 col5" >12.384</td>
#       <td id="T_4f6f3_row1_col6" class="data row1 col6" >3128329.000</td>
#       <td id="T_4f6f3_row1_col7" class="data row1 col7" >218408598817078.094</td>
#       <td id="T_4f6f3_row1_col8" class="data row1 col8" >807706.062</td>
#       <td id="T_4f6f3_row1_col9" class="data row1 col9" >0.100</td>
#     </tr>
#     <tr>
#       <th id="T_4f6f3_level0_row2" class="row_heading level0 row2" >CNN</th>
#       <td id="T_4f6f3_row2_col0" class="data row2 col0" >31.369</td>
#       <td id="T_4f6f3_row2_col1" class="data row2 col1" >32.184</td>
#       <td id="T_4f6f3_row2_col2" class="data row2 col2" >36.916</td>
#       <td id="T_4f6f3_row2_col3" class="data row2 col3" >37.372</td>
#       <td id="T_4f6f3_row2_col4" class="data row2 col4" >35.747</td>
#       <td id="T_4f6f3_row2_col5" class="data row2 col5" >32.952</td>
#       <td id="T_4f6f3_row2_col6" class="data row2 col6" >4664111.000</td>
#       <td id="T_4f6f3_row2_col7" class="data row2 col7" >239656109256295.656</td>
#       <td id="T_4f6f3_row2_col8" class="data row2 col8" >1250428.125</td>
#       <td id="T_4f6f3_row2_col9" class="data row2 col9" >0.121</td>
#     </tr>
#   </tbody>
# </table>

# %%
RMSE_scores = compute_scores(DataFrameMap, "RMSE")

display_min_score(DataFrameMap, RMSE_scores)
# Out:
# <style type="text/css">
# #T_b640a_row1_col0, #T_b640a_row1_col1, #T_b640a_row1_col2, #T_b640a_row1_col3, #T_b640a_row1_col4, #T_b640a_row1_col5, #T_b640a_row1_col6, #T_b640a_row1_col8, #T_b640a_row1_col9, #T_b640a_row2_col7 {
#   background-color: green;
# }
# </style>
# <table id="T_b640a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b640a_level0_col0" class="col_heading level0 col0" >Prev Close</th>
#       <th id="T_b640a_level0_col1" class="col_heading level0 col1" >Open</th>
#       <th id="T_b640a_level0_col2" class="col_heading level0 col2" >High</th>
#       <th id="T_b640a_level0_col3" class="col_heading level0 col3" >Low</th>
#       <th id="T_b640a_level0_col4" class="col_heading level0 col4" >Close</th>
#       <th id="T_b640a_level0_col5" class="col_heading level0 col5" >VWAP</th>
#       <th id="T_b640a_level0_col6" class="col_heading level0 col6" >Volume</th>
#       <th id="T_b640a_level0_col7" class="col_heading level0 col7" >Turnover</th>
#       <th id="T_b640a_level0_col8" class="col_heading level0 col8" >Deliverable Volume</th>
#       <th id="T_b640a_level0_col9" class="col_heading level0 col9" >%Deliverble</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b640a_level0_row0" class="row_heading level0 row0" >LSTM</th>
#       <td id="T_b640a_row0_col0" class="data row0 col0" >34.270</td>
#       <td id="T_b640a_row0_col1" class="data row0 col1" >35.459</td>
#       <td id="T_b640a_row0_col2" class="data row0 col2" >37.755</td>
#       <td id="T_b640a_row0_col3" class="data row0 col3" >34.657</td>
#       <td id="T_b640a_row0_col4" class="data row0 col4" >35.778</td>
#       <td id="T_b640a_row0_col5" class="data row0 col5" >35.752</td>
#       <td id="T_b640a_row0_col6" class="data row0 col6" >8395129.465</td>
#       <td id="T_b640a_row0_col7" class="data row0 col7" >582318649416121.500</td>
#       <td id="T_b640a_row0_col8" class="data row0 col8" >1668535.967</td>
#       <td id="T_b640a_row0_col9" class="data row0 col9" >0.188</td>
#     </tr>
#     <tr>
#       <th id="T_b640a_level0_row1" class="row_heading level0 row1" >RNN</th>
#       <td id="T_b640a_row1_col0" class="data row1 col0" >28.145</td>
#       <td id="T_b640a_row1_col1" class="data row1 col1" >14.573</td>
#       <td id="T_b640a_row1_col2" class="data row1 col2" >21.019</td>
#       <td id="T_b640a_row1_col3" class="data row1 col3" >15.957</td>
#       <td id="T_b640a_row1_col4" class="data row1 col4" >19.445</td>
#       <td id="T_b640a_row1_col5" class="data row1 col5" >24.028</td>
#       <td id="T_b640a_row1_col6" class="data row1 col6" >7199580.516</td>
#       <td id="T_b640a_row1_col7" class="data row1 col7" >614445277626378.000</td>
#       <td id="T_b640a_row1_col8" class="data row1 col8" >1429350.089</td>
#       <td id="T_b640a_row1_col9" class="data row1 col9" >0.122</td>
#     </tr>
#     <tr>
#       <th id="T_b640a_level0_row2" class="row_heading level0 row2" >CNN</th>
#       <td id="T_b640a_row2_col0" class="data row2 col0" >46.709</td>
#       <td id="T_b640a_row2_col1" class="data row2 col1" >52.184</td>
#       <td id="T_b640a_row2_col2" class="data row2 col2" >59.949</td>
#       <td id="T_b640a_row2_col3" class="data row2 col3" >50.860</td>
#       <td id="T_b640a_row2_col4" class="data row2 col4" >51.937</td>
#       <td id="T_b640a_row2_col5" class="data row2 col5" >51.059</td>
#       <td id="T_b640a_row2_col6" class="data row2 col6" >8530788.573</td>
#       <td id="T_b640a_row2_col7" class="data row2 col7" >578568151679219.875</td>
#       <td id="T_b640a_row2_col8" class="data row2 col8" >1908522.769</td>
#       <td id="T_b640a_row2_col9" class="data row2 col9" >0.148</td>
#     </tr>
#   </tbody>
# </table>

# %%
train, test = df[All_Columns].iloc[:num_training_samples], df[All_Columns].iloc[num_training_samples:] 

scaler = StandardScaler() 
train_scaled = pd.DataFrame(scaler.fit_transform(train), index=train.index, columns=train.columns) 
train_diff = train.diff().dropna() 
model = VAR(train_diff) 
model_fit = model.fit(maxlags=2)

lag_order = model_fit.k_ar 

input_data = train.values[-lag_order:] 
steps = len(test) 
VAR_forecast_diff = model_fit.forecast(y=input_data, steps=steps) 

VAR_forecast_diff = pd.DataFrame(VAR_forecast_diff, index=test.index, columns=All_Columns)
last_train = train.iloc[-1]
# Out:
# /opt/conda/lib/python3.13/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
VAR_forecast_diff = model_fit.forecast(y=train_diff.values[-lag_order:], steps=len(actual_last_20)) 
VAR_forecast_cumsum = VAR_forecast_diff.cumsum(axis=0) 
VAR_forecast = VAR_forecast_cumsum + last_train.values 

predicted_last_20_VAR = pd.DataFrame(VAR_forecast, index=actual_last_20.index, columns=All_Columns) 
predicted_last_20_VAR.iloc[0] = last_train.values
print("Predictions:\n", predicted_last_20_VAR)
# Out:
# Predictions:
#              Prev Close        Open        High         Low       Close  \
# Date
# 2018-09-06  380.500000  384.000000  387.700000  380.100000  382.300000
# 2018-09-07  382.532278  384.467762  386.721036  379.061178  382.220640
# 2018-09-10  382.220640  383.199841  386.542815  379.194723  381.922563
# 2018-09-11  381.922563  383.102026  386.434469  378.867309  381.902522
# 2018-09-12  381.902522  383.323141  386.130078  378.738774  381.608936
# ...                ...         ...         ...         ...         ...
# 2021-04-23  249.348127  249.009887  242.749034  255.841003  249.142088
# 2021-04-26  249.142095  248.801396  242.526017  255.649897  248.936055
# 2021-04-27  248.936062  248.592906  242.303000  255.458791  248.730023
# 2021-04-28  248.730029  248.384416  242.079983  255.267685  248.523990
# 2021-04-29  248.523996  248.175925  241.856966  255.076579  248.317957
#
#                   VWAP        Volume      Turnover  Deliverable Volume  \
# Date
# 2018-09-06  384.760000  2.030226e+06  7.811538e+13       670564.000000
# 2018-09-07  383.508237  1.742571e+06  6.698199e+13       674355.520890
# 2018-09-10  383.423615  1.744188e+06  6.577158e+13       612760.941621
# 2018-09-11  383.272791  1.747797e+06  6.610601e+13       629634.168113
# 2018-09-12  382.994316  1.743962e+06  6.582008e+13       637188.326167
# ...                ...           ...           ...                 ...
# 2021-04-23  247.117779  7.802152e+05 -4.962504e+13       422133.365867
# 2021-04-26  246.906431  7.787180e+05 -4.980450e+13       421809.199051
# 2021-04-27  246.695084  7.772208e+05 -4.998395e+13       421485.032234
# 2021-04-28  246.483737  7.757235e+05 -5.016341e+13       421160.865418
# 2021-04-29  246.272389  7.742263e+05 -5.034287e+13       420836.698601
#
#             %Deliverble
# Date
# 2018-09-06     0.330300
# 2018-09-07     0.397208
# 2018-09-10     0.373526
# 2018-09-11     0.382048
# 2018-09-12     0.384008
# ...                 ...
# 2021-04-23     0.418898
# 2021-04-26     0.418955
# 2021-04-27     0.419013
# 2021-04-28     0.419070
# 2021-04-29     0.419128
#
# [652 rows x 10 columns]

# %%
for columns in All_Columns:
    time_series_plot('VAR', columns, predicted_last_20_VAR);

# %%
compareDataMap = {
    "Actual" : actual_df[All_Columns],
    "RNN": predictions_df_RNN[All_Columns],
    "VAR" : predicted_last_20_VAR[All_Columns]
}

compare_MAE_scores = compute_scores(compareDataMap, "MAE")

display_min_score(compareDataMap, compare_MAE_scores)
# Out:
# <style type="text/css">
# #T_e3548_row0_col0, #T_e3548_row0_col1, #T_e3548_row0_col2, #T_e3548_row0_col3, #T_e3548_row0_col4, #T_e3548_row0_col5, #T_e3548_row0_col6, #T_e3548_row0_col7, #T_e3548_row0_col8, #T_e3548_row0_col9 {
#   background-color: green;
# }
# </style>
# <table id="T_e3548">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3548_level0_col0" class="col_heading level0 col0" >Prev Close</th>
#       <th id="T_e3548_level0_col1" class="col_heading level0 col1" >Open</th>
#       <th id="T_e3548_level0_col2" class="col_heading level0 col2" >High</th>
#       <th id="T_e3548_level0_col3" class="col_heading level0 col3" >Low</th>
#       <th id="T_e3548_level0_col4" class="col_heading level0 col4" >Close</th>
#       <th id="T_e3548_level0_col5" class="col_heading level0 col5" >VWAP</th>
#       <th id="T_e3548_level0_col6" class="col_heading level0 col6" >Volume</th>
#       <th id="T_e3548_level0_col7" class="col_heading level0 col7" >Turnover</th>
#       <th id="T_e3548_level0_col8" class="col_heading level0 col8" >Deliverable Volume</th>
#       <th id="T_e3548_level0_col9" class="col_heading level0 col9" >%Deliverble</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3548_level0_row0" class="row_heading level0 row0" >RNN</th>
#       <td id="T_e3548_row0_col0" class="data row0 col0" >12.273</td>
#       <td id="T_e3548_row0_col1" class="data row0 col1" >9.161</td>
#       <td id="T_e3548_row0_col2" class="data row0 col2" >11.210</td>
#       <td id="T_e3548_row0_col3" class="data row0 col3" >10.365</td>
#       <td id="T_e3548_row0_col4" class="data row0 col4" >11.628</td>
#       <td id="T_e3548_row0_col5" class="data row0 col5" >12.384</td>
#       <td id="T_e3548_row0_col6" class="data row0 col6" >3128329.000</td>
#       <td id="T_e3548_row0_col7" class="data row0 col7" >218408598817078.094</td>
#       <td id="T_e3548_row0_col8" class="data row0 col8" >807706.062</td>
#       <td id="T_e3548_row0_col9" class="data row0 col9" >0.100</td>
#     </tr>
#     <tr>
#       <th id="T_e3548_level0_row1" class="row_heading level0 row1" >VAR</th>
#       <td id="T_e3548_row1_col0" class="data row1 col0" >93.756</td>
#       <td id="T_e3548_row1_col1" class="data row1 col1" >94.585</td>
#       <td id="T_e3548_row1_col2" class="data row1 col2" >100.124</td>
#       <td id="T_e3548_row1_col3" class="data row1 col3" >88.681</td>
#       <td id="T_e3548_row1_col4" class="data row1 col4" >94.519</td>
#       <td id="T_e3548_row1_col5" class="data row1 col5" >95.228</td>
#       <td id="T_e3548_row1_col6" class="data row1 col6" >4575340.590</td>
#       <td id="T_e3548_row1_col7" class="data row1 col7" >268614547194931.344</td>
#       <td id="T_e3548_row1_col8" class="data row1 col8" >1109048.461</td>
#       <td id="T_e3548_row1_col9" class="data row1 col9" >0.136</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare_RMSE_scores = compute_scores(compareDataMap, "RMSE")

display_min_score(compareDataMap, compare_RMSE_scores)
# Out:
# <style type="text/css">
# #T_24a16_row0_col0, #T_24a16_row0_col1, #T_24a16_row0_col2, #T_24a16_row0_col3, #T_24a16_row0_col4, #T_24a16_row0_col5, #T_24a16_row0_col6, #T_24a16_row0_col8, #T_24a16_row0_col9, #T_24a16_row1_col7 {
#   background-color: green;
# }
# </style>
# <table id="T_24a16">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_24a16_level0_col0" class="col_heading level0 col0" >Prev Close</th>
#       <th id="T_24a16_level0_col1" class="col_heading level0 col1" >Open</th>
#       <th id="T_24a16_level0_col2" class="col_heading level0 col2" >High</th>
#       <th id="T_24a16_level0_col3" class="col_heading level0 col3" >Low</th>
#       <th id="T_24a16_level0_col4" class="col_heading level0 col4" >Close</th>
#       <th id="T_24a16_level0_col5" class="col_heading level0 col5" >VWAP</th>
#       <th id="T_24a16_level0_col6" class="col_heading level0 col6" >Volume</th>
#       <th id="T_24a16_level0_col7" class="col_heading level0 col7" >Turnover</th>
#       <th id="T_24a16_level0_col8" class="col_heading level0 col8" >Deliverable Volume</th>
#       <th id="T_24a16_level0_col9" class="col_heading level0 col9" >%Deliverble</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_24a16_level0_row0" class="row_heading level0 row0" >RNN</th>
#       <td id="T_24a16_row0_col0" class="data row0 col0" >28.145</td>
#       <td id="T_24a16_row0_col1" class="data row0 col1" >14.573</td>
#       <td id="T_24a16_row0_col2" class="data row0 col2" >21.019</td>
#       <td id="T_24a16_row0_col3" class="data row0 col3" >15.957</td>
#       <td id="T_24a16_row0_col4" class="data row0 col4" >19.445</td>
#       <td id="T_24a16_row0_col5" class="data row0 col5" >24.028</td>
#       <td id="T_24a16_row0_col6" class="data row0 col6" >7199580.516</td>
#       <td id="T_24a16_row0_col7" class="data row0 col7" >614445277626378.000</td>
#       <td id="T_24a16_row0_col8" class="data row0 col8" >1429350.089</td>
#       <td id="T_24a16_row0_col9" class="data row0 col9" >0.122</td>
#     </tr>
#     <tr>
#       <th id="T_24a16_level0_row1" class="row_heading level0 row1" >VAR</th>
#       <td id="T_24a16_row1_col0" class="data row1 col0" >153.625</td>
#       <td id="T_24a16_row1_col1" class="data row1 col1" >154.850</td>
#       <td id="T_24a16_row1_col2" class="data row1 col2" >163.214</td>
#       <td id="T_24a16_row1_col3" class="data row1 col3" >146.286</td>
#       <td id="T_24a16_row1_col4" class="data row1 col4" >154.860</td>
#       <td id="T_24a16_row1_col5" class="data row1 col5" >155.822</td>
#       <td id="T_24a16_row1_col6" class="data row1 col6" >8462644.195</td>
#       <td id="T_24a16_row1_col7" class="data row1 col7" >606252218381784.500</td>
#       <td id="T_24a16_row1_col8" class="data row1 col8" >1801397.175</td>
#       <td id="T_24a16_row1_col9" class="data row1 col9" >0.163</td>
#     </tr>
#   </tbody>
# </table>

# %%
predictResults = [predicted_last_20, predicted_last_20_RNN, predicted_last_20_CNN, predicted_last_20_VAR];
path = "./PredictData/";
fileNames = ["LSTM_PredictResult_Stock.csv", "RNN_PredictResult_Stock.csv", "CNN_PredictResult_Stock.csv", "VAR_PredictResult_Stock.csv"]

for predictResult, fileName in zip(predictResults, fileNames):
    predictResult.to_csv(path + fileName, index="false");

# %%
metricsData = [MAE_scores, RMSE_scores, compare_MAE_scores, compare_RMSE_scores]
metricsFileNames = ["MAE_metrics.csv", "RMSE_metrics.csv", "MAE_Between_RNN_And_VAR.csv", "RMSE_Between_RNN_And_VAR.csv"]

for metricData, metricsFileName in zip(metricsData, metricsFileNames):
    df = pd.DataFrame.from_dict(metricData, orient="index", columns=["score"])
    
    if isinstance(next(iter(metricData.keys())), tuple):
        df.index = pd.MultiIndex.from_tuples(df.index, names=["Column", "Model"])
    
    df.to_csv(path + metricsFileName, index=True)
